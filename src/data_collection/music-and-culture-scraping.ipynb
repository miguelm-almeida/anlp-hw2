# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.12.2)

# %%
import requests
from bs4 import BeautifulSoup
import urllib.parse
import time
from collections import deque
import os
import re
import unicodedata


def extract_text_content(url):
    """
    Extract all text content from a web page using Beautiful Soup

    Args:
        url (str): The URL of the page to scrape

    Returns:
        tuple: (text_content, page_title, links)

    Note:
        Normalizes all line endings to Unix-style '\n' and removes unusual line terminators
    """
    try:
        # Send request to the URL
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        }
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()  # Raise exception for bad status codes

        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract page title
        title = soup.title.text.strip() if soup.title else "No title found"

        # Extract all text
        # Remove script and style elements that might contain text not meant for display
        for script_or_style in soup(['script', 'style', 'meta', 'noscript']):
            script_or_style.decompose()

        # Get all text
        text_content = []

        # Add the title first - ensure no unusual characters in title
        clean_title = unicodedata.normalize('NFKD', title)
        clean_title = re.sub(r'[\r\n\u2028\u2029]', ' ', clean_title)  # Replace line breaks with spaces

        text_content.append(f"TITLE: {clean_title}\n")
        text_content.append(f"URL: {url}\n")
        text_content.append("-" * 50 + "\n\n")

        # Extract headings with hierarchy
        for tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
            for heading in soup.find_all(tag):
                if heading.text.strip():
                    # Add heading with appropriate level indicator
                    level_indicator = "#" * int(tag[1])
                    # Clean heading text of unusual line terminators
                    clean_heading = unicodedata.normalize('NFKD', heading.text.strip())
                    clean_heading = re.sub(r'[\r\n\u2028\u2029]', ' ', clean_heading)
                    text_content.append(f"{level_indicator} {clean_heading}\n\n")

        # Extract paragraphs
        for p in soup.find_all('p'):
            if p.text.strip():
                # Clean paragraph text of unusual line terminators
                clean_para = unicodedata.normalize('NFKD', p.text.strip())
                clean_para = re.sub(r'[\r\n\u2028\u2029]', ' ', clean_para)
                text_content.append(f"{clean_para}\n\n")

        # Get content from div elements that might contain text
        for div in soup.find_all('div'):
            # Only include direct text in divs (not text from child elements)
            direct_text = div.find(string=True, recursive=False)
            if direct_text and direct_text.strip():
                # Clean direct text of unusual line terminators
                clean_text = unicodedata.normalize('NFKD', direct_text.strip())
                clean_text = re.sub(r'[\r\n\u2028\u2029]', ' ', clean_text)
                text_content.append(f"{clean_text}\n\n")

        # Extract all links
        links = []
        for link in soup.find_all('a'):
            href = link.get('href')
            if href:
                links.append({
                    'text': link.text.strip(),
                    'url': href
                })

        # Join all text content
        full_text = "".join(text_content)

        # Normalize line endings and remove unusual line terminators
        # Replace Windows line endings (\r\n) with Unix line endings (\n)
        full_text = full_text.replace('\r\n', '\n')
        # Replace old Mac line endings (\r) with Unix line endings (\n)
        full_text = full_text.replace('\r', '\n')
        # Remove any other unusual line terminators like Line Separator (LS) or Paragraph Separator (PS)
        full_text = full_text.replace('\u2028', '\n')  # Line Separator (LS)
        full_text = full_text.replace('\u2029', '\n')  # Paragraph Separator (PS)
        # Remove any other control characters except normal whitespace
        full_text = re.sub(r'[\x00-\x08\x0B\x0C\x0E-\x1F\x7F]', '', full_text)

        return full_text, title, links
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return f"Error scraping {url}: {e}", "Error", []


def normalize_url(base_url, href):
    """
    Normalize a URL by resolving relative paths and ensuring it's from the same domain

    Args:
        base_url (str): The base URL for resolving relative paths
        href (str): The URL or path to normalize

    Returns:
        str or None: The normalized URL if valid, None otherwise
    """
    try:
        # Parse the base URL to get the domain
        parsed_base = urllib.parse.urlparse(base_url)
        base_domain = parsed_base.netloc

        # Skip if it's a fragment, javascript, mailto, or other non-HTTP scheme
        if not href or href.startswith('#') or href.startswith('javascript:') or href.startswith('mailto:'):
            return None

        # Resolve the URL (handles relative paths)
        full_url = urllib.parse.urljoin(base_url, href)
        parsed_url = urllib.parse.urlparse(full_url)

        # Only return URLs from the same domain and with HTTP/HTTPS scheme
        if parsed_url.netloc == base_domain and parsed_url.scheme in ['http', 'https']:
            # Remove fragments
            return full_url.split('#')[0]
        return None
    except Exception:
        return None


def create_filename_from_url(url, title):
    """
    Create a safe filename from a URL and title

    Args:
        url (str): The URL
        title (str): The page title

    Returns:
        str: A safe filename
    """
    # Extract domain name
    parsed_url = urllib.parse.urlparse(url)
    domain = parsed_url.netloc

    # Extract path and remove trailing slash if present
    path = parsed_url.path.rstrip('/')

    # Replace special characters in the path with underscores
    path = re.sub(r'[^a-zA-Z0-9]', '_', path)

    # Clean the title
    clean_title = re.sub(r'[^a-zA-Z0-9]', '_', title)
    clean_title = re.sub(r'_+', '_', clean_title)  # Replace multiple underscores with a single one
    clean_title = clean_title[:50]  # Limit title length

    # Build the filename
    if path:
        filename = f"{domain}{path}_{clean_title}.txt"
    else:
        filename = f"{domain}_{clean_title}.txt"

    # Ensure filename doesn't have double underscores
    filename = re.sub(r'_+', '_', filename)

    # Ensure filename isn't excessively long
    if len(filename) > 100:
        filename = filename[:100] + ".txt"

    return filename


def crawl_website(start_url, max_pages=100):
    """
    Crawl a website starting from a given URL, up to a maximum number of pages

    Args:
        start_url (str): The URL to start crawling from
        max_pages (int): Maximum number of pages to crawl

    Returns:
        list: List of dictionaries containing data from all crawled pages
    """
    # Parse the start URL to get the domain
    parsed_url = urllib.parse.urlparse(start_url)
    domain = parsed_url.netloc

    # Create a directory for the results if it doesn't exist
    domain_dir = domain.replace(':', '_').replace('/', '_')
    os.makedirs(f'text_results/{domain_dir}', exist_ok=True)

    # Initialize the queue with the start URL
    queue = deque([start_url])

    # Set to keep track of visited URLs
    visited = set([start_url])

    # Counter for the number of pages crawled
    pages_crawled = 0

    print(f"Starting crawl of {domain} from {start_url}")

    while queue and pages_crawled < max_pages:
        # Get the next URL from the queue
        current_url = queue.popleft()

        print(f"Crawling {current_url} ({pages_crawled + 1}/{max_pages})")

        # Extract content from the page
        text_content, title, links = extract_text_content(current_url)

        if text_content:
            # Create a filename for this page
            filename = create_filename_from_url(current_url, title)

            # Save the text content to a file with standardized line endings
            with open(f'text_results/{domain_dir}/{filename}', 'w', encoding='utf-8', newline='\n') as f:
                f.write(text_content)

            print(f"Saved text to text_results/{domain_dir}/{filename}")

            # Increment the counter
            pages_crawled += 1

            # Add new links to the queue
            for link in links:
                href = link['url']
                normalized_url = normalize_url(current_url, href)

                if normalized_url and normalized_url not in visited:
                    queue.append(normalized_url)
                    visited.add(normalized_url)

        # Be nice to the server
        time.sleep(1)

    print(f"Finished crawling {domain}, visited {pages_crawled} pages")
    return pages_crawled


def crawl_multiple_sites(urls, max_pages_per_site=50):
    """
    Crawl multiple websites from a list of starter URLs

    Args:
        urls (list): List of URLs to start crawling from
        max_pages_per_site (int): Maximum number of pages to crawl per site

    Returns:
        dict: Dictionary mapping domains to their crawled content
    """
    # Create main directory for results
    os.makedirs('text_results', exist_ok=True)

    results = {}

    for url in urls:
        try:
            # Parse the URL to get the domain
            parsed_url = urllib.parse.urlparse(url)
            domain = parsed_url.netloc

            print(f"\n{'='*40}\nStarting crawl of {domain}\n{'='*40}")

            # Crawl the website
            pages_crawled = crawl_website(url, max_pages=max_pages_per_site)

            # Store the results
            results[domain] = pages_crawled

            print(f"Crawled {pages_crawled} pages from {domain}")
        except Exception as e:
            print(f"Error crawling {url}: {e}")

    return results


# Define your list of URLs to crawl here
urls_to_crawl = [
    "https://www.pittsburghsymphony.org/",
    "https://pittsburghopera.org/",
    "https://trustarts.org/",
    "https://carnegiemuseums.org/",
    "https://www.heinzhistorycenter.org/",
    "https://www.thefrickpittsburgh.org/",
    "https://www.visitpittsburgh.com/events-festivals/food-festivals/",
    "https://www.picklesburgh.com/",
    "https://www.pghtacofest.com/",
    "https://pittsburghrestaurantweek.com/",
    "https://littleitalydays.com/",
    "https://bananasplitfest.com/"
]

# Set the maximum number of pages to crawl per site
max_pages_per_site = 50

# Call the function with your list of URLs
results = crawl_multiple_sites(urls_to_crawl, max_pages_per_site=max_pages_per_site)

print("\nCrawl complete!")
print("Summary of pages crawled:")
for domain, count in results.items():
    print(f"  - {domain}: {count} pages")
print(f"Results saved to the 'text_results' directory")
# Out:
# ========================================
# Starting crawl of www.pittsburghsymphony.org
# ========================================
# Starting crawl of www.pittsburghsymphony.org from https://www.pittsburghsymphony.org/
# Crawling https://www.pittsburghsymphony.org/ (1/50)
# Error scraping https://www.pittsburghsymphony.org/: 403 Client Error: HTTP Forbidden for url: https://www.pittsburghsymphony.org/?queueittoken=e_trustsitewide~ts_1741729657~ce_true~rt_safetynet~h_c8a0f2f8daff8d0b68a7e4377ea5622347f5135beb8621f7cae9427bbfa42a31
# Saved text to text_results/www.pittsburghsymphony.org/www.pittsburghsymphony.org_Error.txt
# Finished crawling www.pittsburghsymphony.org, visited 1 pages
# Crawled 1 pages from www.pittsburghsymphony.org
#
# ========================================
# Starting crawl of pittsburghopera.org
# ========================================
# Starting crawl of pittsburghopera.org from https://pittsburghopera.org/
# Crawling https://pittsburghopera.org/ (1/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_Home_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org?hsLang=en (2/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_Home_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/calendar?hsLang=en (3/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_calendar_Pittsburgh_Opera_s_Calendar_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/about?hsLang=en (4/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_about_About_Pittsburgh_Opera_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/about/operamyths/?hsLang=en (5/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_about_operamyths_Opera_Mythbusting_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/about/mission-history?hsLang=en (6/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_about_mission_history_Pittsburgh_Opera_Mission_and_History_Pittsburgh_Op.txt
# Crawling https://pittsburghopera.org/about/inclusion-diversity-equity-accessibility-idea/?hsLang=en (7/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_about_inclusion_diversity_equity_accessibility_idea_Inclusion_Diversity_Equity_A.txt
# Crawling https://pittsburghopera.org/about/financial-documents?hsLang=en (8/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_about_financial_documents_Pittsburgh_Opera_Public_Financial_Documents_Pittsb.txt
# Crawling https://pittsburghopera.org/season/madama-butterfly?hsLang=en (9/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_madama_butterfly_MADAMA_BUTTERFLY_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season?hsLang=en (10/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_Pittsburgh_Opera_2024_25_Season_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/woman-with-eyes-closed?hsLang=en (11/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_woman_with_eyes_closed_WOMAN_WITH_EYES_CLOSED_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/boheme?hsLang=en (12/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_boheme_LA_BOHEME_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/fellow-travelers?hsLang=en (13/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_fellow_travelers_FELLOW_TRAVELERS_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/curlew-river?hsLang=en (14/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_curlew_river_CURLEW_RIVER_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/falstaff?hsLang=en (15/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_falstaff_FALSTAFF_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/past-seasons?hsLang=en (16/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_past_seasons_Pittsburgh_Opera_past_seasons_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/season/free-low-cost-events?hsLang=en (17/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_free_low_cost_events_Pittsburgh_Opera_Free_Low_Cost_Events_Pittsburgh_O.t.txt
# Crawling https://pittsburghopera.org/season/special-events?hsLang=en (18/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_season_special_events_Pittsburgh_Opera_Special_Events_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets?hsLang=en (19/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_Pittsburgh_Opera_tickets_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/subscribe-today?hsLang=en (20/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_subscribe_today_Pittsburgh_Opera_Season_Tickets_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/season-pass?hsLang=en (21/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_season_pass_Opus_Pass_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/groups-tickets?hsLang=en (22/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_groups_tickets_Pittsburgh_Opera_Group_Services_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/promotions-and-discounts/?hsLang=en (23/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_promotions_and_discounts_Promotions_and_Discounts_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/student-tickets?hsLang=en (24/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_student_tickets_Student_Tickets_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/give-the-gift-of-opera/?hsLang=en (25/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_give_the_gift_of_opera_Give_the_Gift_of_Opera_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/ticket-offices-policies/?hsLang=en (26/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_ticket_offices_policies_Pittsburgh_Opera_ticketing_information_and_polic.txt
# Crawling https://pittsburghopera.org/tickets/accessibility/?hsLang=en (27/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_accessibility_Pittsburgh_Opera_Accessibility_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/opera-faqs/?hsLang=en (28/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_opera_faqs_Pittsburgh_Opera_FAQs_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/free-rideshare-vouchers/?hsLang=en (29/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_free_rideshare_vouchers_Free_Rideshare_Vouchers_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/tickets/free-childcare-services?hsLang=en (30/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_tickets_free_childcare_services_Free_Childcare_Services_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support?hsLang=en (31/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_Support_Pittsburgh_Opera_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/ways-to-give?hsLang=en (32/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_ways_to_give_Give_Now_to_Pittsburgh_Opera_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/give-now?hsLang=en (33/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_give_now_Pittsburgh_Opera_Contributor_Benefits_Pittsburgh_O.txt
# Crawling https://pittsburghopera.org/support/sustaining-giving?hsLang=en (34/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_sustaining_giving_Sustaining_Giving_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/corporate-giving?hsLang=en (35/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_corporate_giving_Corporate_Giving_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/matching-gift-program?hsLang=en (36/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_matching_gift_program_Matching_Gift_Program_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/advertise-with-us?hsLang=en (37/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_advertise_with_us_Advertise_With_Us_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/foundation-support?hsLang=en (38/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_foundation_support_Foundation_Support_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/government-support?hsLang=en (39/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_government_support_Government_Support_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/monteverdi?hsLang=en (40/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_monteverdi_Monteverdi_Society_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/forever?hsLang=en (41/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_forever_Forever_Campaign_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/support/volunteer?hsLang=en (42/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_support_volunteer_Volunteer_at_Pittsburgh_Opera_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/education?hsLang=en (43/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_Pittsburgh_Opera_Education_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/education/educators?hsLang=en (44/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_educators_Pittsburgh_Opera_programs_and_resources_for_Educat.txt
# Crawling https://pittsburghopera.org/education/students?hsLang=en (45/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_students_Pittsburgh_Opera_Education_Students_Pittsburgh_Ope.txt
# Crawling https://pittsburghopera.org/education/schools?hsLang=en (46/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_schools_Pittsburgh_Opera_Education_Schools_Pittsburgh_Oper.txt
# Crawling https://pittsburghopera.org/education/families?hsLang=en (47/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_families_Pittsburgh_Opera_Education_Families_Pittsburgh_Ope.txt
# Crawling https://pittsburghopera.org/education/adults?hsLang=en (48/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_adults_Pittsburgh_Opera_Education_Adults_Pittsburgh_Opera.txt
# Crawling https://pittsburghopera.org/education/resources?hsLang=en (49/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_resources_Pittsburgh_Opera_Education_Resources_Pittsburgh_Op.txt
# Crawling https://pittsburghopera.org/education/mobile-app?hsLang=en (50/50)
# Saved text to text_results/pittsburghopera.org/pittsburghopera.org_education_mobile_app_Mobile_App_Pittsburgh_Opera.txt
# Finished crawling pittsburghopera.org, visited 50 pages
# Crawled 50 pages from pittsburghopera.org
#
# ========================================
# Starting crawl of trustarts.org
# ========================================
# Starting crawl of trustarts.org from https://trustarts.org/
# Crawling https://trustarts.org/ (1/50)
# Error scraping https://trustarts.org/: 403 Client Error: HTTP Forbidden for url: https://trustarts.org/?queueittoken=e_trustsitewide~ts_1741729725~ce_true~rt_safetynet~h_e87436d5f79cf10cd717aee609cd3b69fbe9b199c73239cd856214f7007e593b
# Saved text to text_results/trustarts.org/trustarts.org_Error.txt
# Finished crawling trustarts.org, visited 1 pages
# Crawled 1 pages from trustarts.org
#
# ========================================
# Starting crawl of carnegiemuseums.org
# ========================================
# Starting crawl of carnegiemuseums.org from https://carnegiemuseums.org/
# Crawling https://carnegiemuseums.org/ (1/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_Home_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/joinrenew/ (2/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_joinrenew_Become_a_Member_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/timed-tickets/ (3/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_timed_tickets_Timed_Tickets_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/plan-a-visit (4/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_plan_a_visit_Plan_a_Visit_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/things-to-do/ (5/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_Things_to_Do_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/things-to-do/view-our-exhibitions/ (6/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_view_our_exhibitions_View_Our_Exhibitions_Carnegie_Museums_of_Pitts.txt
# Crawling https://carnegiemuseums.org/things-to-do/explore-our-collections/ (7/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_explore_our_collections_Explore_Our_Collections_Carnegie_Museums_of.txt
# Crawling https://carnegiemuseums.org/things-to-do/learn-with-us/ (8/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_learn_with_us_Learn_With_Us_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/events/ (9/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_events_Events_Archive_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/plan-a-visit/ (10/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_plan_a_visit_Plan_a_Visit_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/ (11/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_Membership_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/members-only-events/ (12/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_members_only_events_Member_Events_Carnegie_Museums_of_Pi.txt
# Crawling https://carnegiemuseums.org/join-support/membership/benefits/ (13/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_benefits_Benefits_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/faq/ (14/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_faq_Membership_FAQs_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/reciprocal-privileges/ (15/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_reciprocal_privileges_Reciprocal_Privileges_Carnegie_Mus.txt
# Crawling https://carnegiemuseums.org/join-support/ (16/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_Join_Support_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/donate/ (17/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_donate_Support_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/membership/teen-membership/ (18/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_teen_membership_A_Free_Membership_Just_for_Teens_Carnegi.txt
# Crawling https://carnegiemuseums.org/join-support/membership/access-for-all/ (19/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_access_for_all_Access_for_All_Carnegie_Museums_of_Pittsb.txt
# Crawling https://carnegiemuseums.org/carnegieconnectors/ (20/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegieconnectors_Carnegie_Connectors_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/join-support/donate/corporate-gifts/ (21/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_donate_corporate_gifts_Corporate_Giving_Carnegie_Museums_of_Pittsbu.txt
# Crawling https://carnegiemuseums.org/great-event-spaces/ (22/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_great_event_spaces_Great_Event_Spaces_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/carnegie-museums-in-oakland/ (23/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_museums_in_oakland_Carnegie_Museums_in_Oakland_Carnegie_Museums_of_Pi.t.txt
# Crawling https://carnegiemuseums.org/carnegie-science-center/ (24/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_science_center_Carnegie_Science_Center_Carnegie_Museums_of_Pittsb.txt
# Crawling https://carnegiemuseums.org/the-andy-warhol-museum/ (25/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_the_andy_warhol_museum_The_Andy_Warhol_Museum_Carnegie_Museums_of_Pittsbu.txt
# Crawling https://carnegiemuseums.org/weddings-at-the-museums/ (26/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_weddings_at_the_museums_Weddings_at_the_Museums_Carnegie_Museums_of_Pittsb.txt
# Crawling https://carnegiemuseums.org/contact-us/ (27/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/ (28/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_Carnegie_magazine_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/tag/art/ (29/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_art_Art_Archives_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/tag/science-nature/ (30/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_science_nature_Science_Nature_Archives_Carnegie_Museums_of_Pittsb.txt
# Crawling https://carnegiemuseums.org/tag/face-time/ (31/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_face_time_Facetime_Q_A_Archives_Carnegie_Museums_of_Pittsbur.txt
# Crawling https://carnegiemuseums.org/tag/behind-scenes/ (32/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_behind_scenes_Behind_the_Scenes_Archives_Carnegie_Museums_of_Pit.txt
# Crawling https://carnegiemuseums.org/tag/the-inclusive-museum/ (33/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_the_inclusive_museum_The_Inclusive_Museum_Archives_Carnegie_Museums_of_.txt
# Crawling https://carnegiemuseums.org/tag/community/ (34/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_community_Community_Archives_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/tag/stem/ (35/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_stem_STEM_Archives_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/tag/carnegie-international/ (36/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_carnegie_international_Carnegie_International_Archives_Carnegie_Museums_o.tx.txt
# Crawling https://carnegiemuseums.org/tag/where-art-science-meet/ (37/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_tag_where_art_science_meet_Where_Art_Science_Meet_Archives_Carnegie_Museums_o.tx.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/current-issue/ (38/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_current_issue_Winter_2024_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/carnegie-magazine-archive/ (39/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_carnegie_magazine_archive_Carnegie_magazine_Archive_Carnegie_M.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/subscribe/ (40/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_subscribe_Subscribe_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/advertise/ (41/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_advertise_Advertise_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/carnegie-magazine/contact-us/ (42/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/about-us/ (43/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_About_Us_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/about-us/our-history/ (44/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_history_Our_History_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/about-us/our-museums/ (45/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_museums_Our_Museums_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/mission-and-core-values/ (46/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_mission_and_core_values_Mission_and_Core_Values_Carnegie_Museums_of_Pittsb.txt
# Crawling https://carnegiemuseums.org/about-us/our-impact/ (47/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_impact_Our_Impact_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/about-us/leadership/ (48/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_leadership_Leadership_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/opportunities/ (49/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_opportunities_Opportunities_Carnegie_Museums_of_Pittsburgh.txt
# Crawling https://carnegiemuseums.org/about-us/contact-us/ (50/50)
# Saved text to text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt
# Finished crawling carnegiemuseums.org, visited 50 pages
# Crawled 50 pages from carnegiemuseums.org
#
# ========================================
# Starting crawl of www.heinzhistorycenter.org
# ========================================
# Starting crawl of www.heinzhistorycenter.org from https://www.heinzhistorycenter.org/
# Crawling https://www.heinzhistorycenter.org/ (1/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_Home_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/history-center/ (2/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_history_center_Heinz_History_Center_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/sports-museum/ (3/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_sports_museum_Western_Pennsylvania_Sports_Museum_Heinz_History_C.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/fort-pitt/ (4/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_fort_pitt_Fort_Pitt_Museum_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/meadowcroft/ (5/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_meadowcroft_Meadowcroft_Rockshelter_and_Historic_Village_Heinz.t.txt
# Crawling https://www.heinzhistorycenter.org/join/ (6/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_join_Become_a_Member_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/give/make-a-donation/ (7/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_make_a_donation_Make_a_Donation_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/search/ (8/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_search_Search_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/heinz-history-center/ (9/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_heinz_history_center_Heinz_History_Center_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/sports-museum/ (10/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_sports_museum_Western_Pennsylvania_Sports_Museum_Heinz_History_C.tx.txt
# Crawling https://www.heinzhistorycenter.org/visit/fort-pitt/ (11/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_fort_pitt_Fort_Pitt_Museum_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/meadowcroft/ (12/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_meadowcroft_Meadowcroft_Rockshelter_and_Historic_Village_Heinz.txt
# Crawling https://www.heinzhistorycenter.org/event/american-girlhood-a-window-into-history/ (13/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_american_girlhood_a_window_into_history_American_Girlhood_A_Window_.txt
# Crawling https://www.heinzhistorycenter.org/events/ (14/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_events_Events_for_March_2025_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/event/national-history-day-pittsburgh-03152025/ (15/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_national_history_day_pittsburgh_03152025_National_History_Day_Pitts.txt
# Crawling https://www.heinzhistorycenter.org/event/vietnam-veterans-day-50th-anniversary-commemoration-2025/ (16/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_vietnam_veterans_day_50th_anniversary_commemoration_2025_Vietnam_Ve.txt
# Crawling https://www.heinzhistorycenter.org/event/vintage-pittsburgh-2025/ (17/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_vintage_pittsburgh_2025_Vintage_Pittsburgh_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/event/spring-educator-open-house/ (18/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_spring_educator_open_house_Spring_Educator_Open_House_Heinz_History.txt
# Crawling https://www.heinzhistorycenter.org/research/detre-library-archives/ (19/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_detre_library_archives_Detre_Library_Archives_Heinz_History_Cent.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/exhibits/ (20/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_exhibits_Exhibits_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/families/ (21/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_families_Kids_Families_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/about/the-smithsonians-home-in-pittsburgh/ (22/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_the_smithsonians_home_in_pittsburgh_The_Smithsonian_s_Home_in_Pitts.txt
# Crawling https://www.heinzhistorycenter.org/research/explore/ (23/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_explore_Explore_Our_Collections_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/about/ (24/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_About_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/about/contact-us/ (25/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_contact_us_Contact_Us_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/accessibility/ (26/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_accessibility_Accessibility_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/health-safety/ (27/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_health_safety_Health_Safety_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/about/work-with-us/ (28/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_work_with_us_Work_With_Us_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/sitemap/ (29/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_sitemap_Sitemap_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/policies/ (30/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_policies_Policies_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/cdn-cgi/l/email-protection (31/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_cdn_cgi_l_email_protection_Email_Protection_Cloudflare.txt
# Crawling https://www.heinzhistorycenter.org/about/event-rentals/ (32/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_event_rentals_Event_Rentals_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/visit/ (33/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_Visit_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/whats-on/ (34/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_What_s_On_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/research/ (35/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_Research_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/research/african-american-program/ (36/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_african_american_program_African_American_Program_Heinz_History_.txt
# Crawling https://www.heinzhistorycenter.org/research/rauh-jewish-history-program-archives/ (37/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_rauh_jewish_history_program_archives_Rauh_Jewish_History_Program.txt
# Crawling https://www.heinzhistorycenter.org/research/italian-american-program/ (38/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_italian_american_program_Italian_American_Program_Heinz_History_.txt
# Crawling https://www.heinzhistorycenter.org/research/publications/ (39/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_publications_Publications_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/research/contribute-to-our-collections/ (40/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_contribute_to_our_collections_Contribute_to_Our_Collections_Hein.txt
# Crawling https://www.heinzhistorycenter.org/give/ (41/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_Join_Give_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/give/fundraising-events/ (42/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_fundraising_events_Fundraising_Events_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/give/commemorative-gifts/ (43/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_commemorative_gifts_Commemorative_Gifts_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/give/planned-giving/ (44/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_planned_giving_Planned_Giving_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/learn/ (45/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_Learn_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/learn/education/ (46/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_education_For_Schools_Teachers_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/learn/scout-programs/ (47/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_scout_programs_Scout_Programs_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/learn/america-101/ (48/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_america_101_America_101_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/learn/virtual-tours/ (49/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_virtual_tours_Virtual_Tours_Heinz_History_Center.txt
# Crawling https://www.heinzhistorycenter.org/blog/ (50/50)
# Saved text to text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_blog_Blog_Posts_Archive_Heinz_History_Center.txt
# Finished crawling www.heinzhistorycenter.org, visited 50 pages
# Crawled 50 pages from www.heinzhistorycenter.org
#
# ========================================
# Starting crawl of www.thefrickpittsburgh.org
# ========================================
# Starting crawl of www.thefrickpittsburgh.org from https://www.thefrickpittsburgh.org/
# Crawling https://www.thefrickpittsburgh.org/ (1/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Home_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/stories (2/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_stories_Stories_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/calendar (3/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_calendar_Calendar_of_Events_The_Frick_Pittsburgh_Museums_Ga.txt
# Crawling https://www.thefrickpittsburgh.org/equity (4/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_equity_Equity_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/membership (5/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_membership_Membership_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/rentals (6/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_rentals_Rental_Events_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/cafe (7/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_cafe_The_Cafe_at_the_Frick_The_Frick_Pittsburgh_Museums.txt
# Crawling https://www.thefrickpittsburgh.org/store (8/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_store_Store_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/plan-your-visit (9/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_plan_your_visit_Plan_Your_Visit_The_Frick_Pittsburgh_Museums_Garde.txt
# Crawling https://www.thefrickpittsburgh.org/plan-your-visit (10/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_plan_your_visit_Plan_Your_Visit_The_Frick_Pittsburgh_Museums_Garde.txt
# Crawling http://www.thefrickpittsburgh.org/Files/Admin/TheFrickPittsburghSiteMap2022.pdf?d=2022727165656 (11/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Files_Admin_TheFrickPittsburghSiteMap2022_pdf_No_title_found.txt
# Crawling https://www.thefrickpittsburgh.org/accessibility (12/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_accessibility_Accessibility_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/tours (13/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_tours_Tours_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/groupvisits (14/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_groupvisits_Group_Visits_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/learn (15/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_learn_Learning_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/see-and-do (16/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_see_and_do_See_and_Do_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/see-and-do (17/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_see_and_do_See_and_Do_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/learn (18/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_learn_Learning_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/virtual (19/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_virtual_Virtual_Experiences_The_Frick_Pittsburgh_Museums_G.txt
# Crawling http://www.thefrickpittsburgh.org/exhibitions (20/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_exhibitions_Exhibitions_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/exhibitions (21/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_exhibitions_Exhibitions_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/past-exhibitions (22/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_past_exhibitions_Past_Exhibitions_The_Frick_Pittsburgh_Museums_Gard.txt
# Crawling https://www.thefrickpittsburgh.org/virtualexhibitions (23/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_virtualexhibitions_Virtual_Exhibitions_The_Frick_Pittsburgh_Museums_G.txt
# Crawling https://www.thefrickpittsburgh.org/Exhibition-Kara-Walker-Harpers-Pictorial-History-of-the-Civil-War-Annotated (24/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Exhibition_Kara_Walker_Harpers_Pictorial_History_of_the_Civil_War_Annotat.txt
# Crawling http://www.thefrickpittsburgh.org/collection (25/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_collection_Collection_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/support (26/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_support_Support_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/the-frick-societies (27/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_the_frick_societies_The_Frick_Societies_The_Frick_Pittsburgh_Museums_G.tx.txt
# Crawling http://www.thefrickpittsburgh.org/reciprocal-museums (28/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_reciprocal_museums_Reciprocal_Museums_The_Frick_Pittsburgh_Museums_Ga.txt
# Crawling http://www.thefrickpittsburgh.org/donate (29/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_donate_Donate_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/LegacyPlanning (30/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_LegacyPlanning_Legacy_Planning_The_Frick_Pittsburgh_Museums_Garde.txt
# Crawling http://www.thefrickpittsburgh.org/gifts-of-stock (31/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_gifts_of_stock_Gifts_of_Stock_The_Frick_Pittsburgh_Museums_Garden.txt
# Crawling http://www.thefrickpittsburgh.org/Qualified-Charitable-Distributions (32/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Qualified_Charitable_Distributions_Qualified_Charitable_Distributions_The.txt
# Crawling http://www.thefrickpittsburgh.org/corporate-giving (33/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_corporate_giving_Corporate_Giving_The_Frick_Pittsburgh_Museums_Gard.txt
# Crawling http://www.thefrickpittsburgh.org/eitc (34/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_eitc_EITC_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling http://www.thefrickpittsburgh.org/oursupporters (35/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_oursupporters_Our_Supporters_The_Frick_Pittsburgh_Museums_Garden.txt
# Crawling https://www.thefrickpittsburgh.org/tickets (36/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_tickets_Tickets_The_Frick_Pittsburgh_Museums_Gardens.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Signature-Clayton-Tour-Experience-Gilded-Not-Golden (37/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Signature_Clayton_Tour_Experience_Gilded_Not_Golden_Clayton_Guided_.txt
# Crawling https://www.thefrickpittsburgh.org/carandcarriagemuseum (38/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_carandcarriagemuseum_Car_and_Carriage_Museum_The_Frick_Pittsburgh_Museu.t.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Duquesne-SoundWalk-at-the-Frick (39/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Duquesne_SoundWalk_at_the_Frick_Duquesne_SoundWalk_at_the_Frick_The.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Car-and-Carriage-Museum (40/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Car_and_Carriage_Museum_Car_and_Carriage_Museum_The_Frick_Pittsburg.txt
# Crawling https://www.thefrickpittsburgh.org/Event-The-Frick-Art-Museum (41/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_The_Frick_Art_Museum_Permanent_Collection_The_Frick_Pittsburgh_Muse.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Gallery-Conversations-in-Kara-Walker-Harpers-Pictorial-History-of-the-Civil-War-Annotated-1 (42/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Gallery_Conversations_in_Kara_Walker_Harpers_Pictorial_History_of_t.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Gallery-Conversations-in-Kara-Walker-Harpers-Pictorial-History-of-the-Civil-War-Annotated-2 (43/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Gallery_Conversations_in_Kara_Walker_Harpers_Pictorial_History_of_t.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Echoes-An-Evening-of-Music-with-KEA (44/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Echoes_An_Evening_of_Music_with_KEA_Echoes_An_Evening_of_Music_with.txt
# Crawling https://www.thefrickpittsburgh.org/Event-The-Art-of-the-Crucifixion-From-Anguish-to-Absurdity (45/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_The_Art_of_the_Crucifixion_From_Anguish_to_Absurdity_The_Art_of_the.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Guided-Evening-Tour-of-Kara-Walker-Harpers-Pictorial-History-of-the-Civil-War-Annotated-April (46/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Guided_Evening_Tour_of_Kara_Walker_Harpers_Pictorial_History_of_the.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Book-Talk-Dr-Edda-Fields-Black-on-Harriet-Tubman-and-the-Combahee-River-Raid (47/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Book_Talk_Dr_Edda_Fields_Black_on_Harriet_Tubman_and_the_Combahee_R.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Guest-Label-Writers-in-Conversation (48/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Guest_Label_Writers_in_Conversation_Guest_Label_Writers_in_Conversa.txt
# Crawling https://www.thefrickpittsburgh.org/Event-Guided-Evening-Tour-of-Kara-Walker-Harpers-Pictorial-History-of-the-Civil-War-Annotated-May (49/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Guided_Evening_Tour_of_Kara_Walker_Harpers_Pictorial_History_of_the.txt
# Crawling https://www.thefrickpittsburgh.org/staff (50/50)
# Saved text to text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_staff_Staff_The_Frick_Pittsburgh_Museums_Gardens.txt
# Finished crawling www.thefrickpittsburgh.org, visited 50 pages
# Crawled 50 pages from www.thefrickpittsburgh.org
#
# ========================================
# Starting crawl of www.visitpittsburgh.com
# ========================================
# Starting crawl of www.visitpittsburgh.com from https://www.visitpittsburgh.com/events-festivals/food-festivals/
# Crawling https://www.visitpittsburgh.com/events-festivals/food-festivals/ (1/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_food_festivals_Pittsburgh_Food_Festivals_Greek_Oktoberfest_.txt
# Crawling https://www.visitpittsburgh.com/ (2/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_Visit_Pittsburgh_Official_Tourism_Site_for_Pittsbu.txt
# Crawling https://www.visitpittsburgh.com/plan-your-trip/newsletter-signup/ (3/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_newsletter_signup_Sign_Up_For_Pittsburgh_s_Newsletter_Tips_In.txt
# Crawling https://www.visitpittsburgh.com/plan-your-trip/weather/ (4/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_weather_Pittsburgh_Climate_and_Average_Weather_by_Month_Vi.tx.txt
# Crawling https://www.visitpittsburgh.com/itinerary/ (5/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_itinerary_Saved_Items_Visit_Pittsburgh.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/ (6/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_Fun_Things_to_Do_in_Pittsburgh_Visit_Pittsburgh.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/free-things-to-do/ (7/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_free_things_to_do_Free_Things_to_Do_in_Pittsburgh_Today_Visit_P.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/family-fun/ (8/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_family_fun_Things_to_do_in_Pittsburgh_with_Kids_Visit_Pittsbu.t.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/tours-sightseeing/ (9/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_tours_sightseeing_Pittsburgh_Sightseeing_Tours_Visit_Pittsburgh.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/outdoor-adventure/ (10/50)
# Saved text to text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_outdoor_adventure_Outdoor_Recreation_in_Pittsburgh_Golf_Trails_.txt
# Crawling https://www.visitpittsburgh.com/things-to-do/arts-culture/ (11/50)
# ...
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2014_02_WesBanco_jpg_No_title_found.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2024/12/2025-Bloomfield-LID-Contract-Bloomfield-Guests.pdf (32/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_12_2025_Bloomfield_LID_Contract_Bloomfield_Guests_pdf_No.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2024/08/2024-LID-Setup.pdf (33/50)
# Error scraping http://littleitalydays.com/wp-content/uploads/2024/08/2024-LID-Setup.pdf: 404 Client Error: Not Found for url: http://littleitalydays.com/wp-content/uploads/2024/08/2024-LID-Setup.pdf
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_08_2024_LID_Setup_pdf_Error.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2024/01/2024-Bloomfield-LID-Contract-Bloomfield-Businesses.pdf (34/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_01_2024_Bloomfield_LID_Contract_Bloomfield_Businesses_pd.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2019/07/2019-LID-vendor-map.pdf (35/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_07_2019_LID_vendor_map_pdf_No_title_found.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2021/08/porta-john-map.pdf (36/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2021_08_porta_john_map_pdf_No_title_found.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2014/03/BigDaySmall.jpg (37/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2014_03_BigDaySmall_jpg_No_title_found.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2019/10/2019-Report-to-Community-2.pdf (38/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_10_2019_Report_to_Community_2_pdf_No_title_found.txt
# Crawling http://littleitalydays.com/ (39/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_Little_Italy_Days_Italian_Festival.txt
# Crawling http://littleitalydays.com/entertainment-schedule/ (40/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_entertainment_schedule_Entertainment_Schedule_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/vendor/ (41/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_vendor_Vendor_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/faq/ (42/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_faq_FAQ_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/about-us/ (43/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_about_us_About_Us_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/bloomfield-businesses/ (44/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_bloomfield_businesses_Bloomfield_Businesses_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/community-report/ (45/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_community_report_Community_Report_Little_Italy_Days.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2017/07/13995538_1752240328322087_1800593659089128617_o.jpg (46/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_13995538_1752240328322087_1800593659089128617_o_jpg_N.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2017/07/13996229_1752240551655398_123428501207492172_o.jpg (47/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_13996229_1752240551655398_123428501207492172_o_jpg_No.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2017/07/20106327_736952729809909_8692393511896291482_n.jpg (48/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_20106327_736952729809909_8692393511896291482_n_jpg_No.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2017/07/14088430_574706156034568_6149722159653816399_n.jpg (49/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_14088430_574706156034568_6149722159653816399_n_jpg_No.txt
# Crawling http://littleitalydays.com/wp-content/uploads/2017/07/girls2B.jpg (50/50)
# Saved text to text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_girls2B_jpg_No_title_found.txt
# Finished crawling littleitalydays.com, visited 50 pages
# Crawled 50 pages from littleitalydays.com
#
# ========================================
# Starting crawl of bananasplitfest.com
# ========================================
# Starting crawl of bananasplitfest.com from https://bananasplitfest.com/
# Crawling https://bananasplitfest.com/ (1/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_The_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com (2/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_The_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/activities/ (3/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_Activities_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/events/princess-pageant/ (4/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_princess_pageant_Banana_Split_Princess_Great_American_Banana_Split_.txt
# Crawling https://bananasplitfest.com/activities/crafts-games-activities/ (5/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_crafts_games_activities_Crafts_Games_Activities_Great_American_Banana.txt
# Crawling https://bananasplitfest.com/activities/participating-vendors/ (6/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_participating_vendors_Participating_Vendors_Great_American_Banana_Spl.txt
# Crawling https://bananasplitfest.com/activities/food/ (7/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_food_Eat_Drink_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/activities/over-21-area/ (8/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_over_21_area_Over_21_Area_Great_American_Banana_Split_Celebrati.txt
# Crawling https://bananasplitfest.com/events/ (9/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_Events_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/events/5k-banana-run/ (10/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_5k_banana_run_5K_Banana_Run_Great_American_Banana_Split_Celebrat.txt
# Crawling https://bananasplitfest.com/events/banana-challenge/ (11/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_banana_challenge_Dole_Great_American_Banana_Challenge_Great_America.txt
# Crawling https://bananasplitfest.com/events/blood-drive/ (12/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_blood_drive_Blood_Drive_Great_American_Banana_Split_Celebratio.txt
# Crawling https://bananasplitfest.com/events/cornhole-tournament/ (13/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_cornhole_tournament_Cornhole_Tournament_Great_American_Banana_Split_Ce.tx.txt
# Crawling https://bananasplitfest.com/events/car-show/ (14/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_car_show_Car_Show_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/events/yellow-tie-gala/ (15/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_yellow_tie_gala_Yellow_Tie_Gala_Great_American_Banana_Split_Celebr.txt
# Crawling https://bananasplitfest.com/activities/entertainment/ (16/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_entertainment_Entertainment_Great_American_Banana_Split_Celebrat.txt
# Crawling https://bananasplitfest.com/information/ (17/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_Information_Great_American_Banana_Split_Celebratio.txt
# Crawling https://bananasplitfest.com/schedule/ (18/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_schedule_Schedule_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/information/event-map/ (19/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_event_map_Event_Map_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/information/parking/ (20/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_parking_Parking_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/information/plan-your-visit/ (21/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_plan_your_visit_Plan_Your_Visit_Great_American_Banana_Split_Celebr.t.txt
# Crawling https://bananasplitfest.com/history (22/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_history_History_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/history/ (23/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_history_History_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/information/media/ (24/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_media_Media_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/sponsorship-opportunities/ (25/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_sponsorship_opportunities_Sponsorship_Opportunities_Great_American_Banana_Sp.txt
# Crawling https://bananasplitfest.com/vendors/ (26/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_vendors_Vendors_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/volunteer/ (27/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_volunteer_Volunteer_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/plan-your-visit/ (28/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_plan_your_visit_Plan_Your_Visit_Great_American_Banana_Split_Celebr.txt
# Crawling https://bananasplitfest.com/vendors (29/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_vendors_Vendors_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/entertainment (30/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_entertainment_Entertainment_Great_American_Banana_Split_Celebrat.txt
# Crawling https://bananasplitfest.com/activities (31/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_Activities_Great_American_Banana_Split_Celebration.txt
# Crawling https://bananasplitfest.com/activities/entertainment/entertainer-interest-form/ (32/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_entertainment_entertainer_interest_form_Entertainer_Interest_Form_Gre.txt
# Crawling https://bananasplitfest.com/activities/entertainment (33/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_entertainment_Entertainment_Great_American_Banana_Split_Celebrat.txt
# Crawling https://bananasplitfest.com/activities/over-21-area (34/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_activities_over_21_area_Over_21_Area_Great_American_Banana_Split_Celebrati.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/05/Pageant-1.jpg (35/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_Pageant_1_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/05/pageant11.jpg (36/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant11_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/05/pageant10.jpg (37/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant10_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/05/pageant1.jpg (38/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant1_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/05/pageant3.jpg (39/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant3_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240824_185402-scaled.jpg (40/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240824_185402_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240824_190104-scaled.jpg (41/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240824_190104_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_095856-scaled.jpg (42/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_095856_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_095856-1-scaled.jpg (43/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_095856_1_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_140832-scaled.jpg (44/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_140832_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_140837-scaled.jpg (45/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_140837_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_143534-scaled.jpg (46/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_143534_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/20240825_145556-scaled.jpg (47/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_145556_scaled_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/wp-content/uploads/2024/08/D9B572A5-.jpg (48/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_D9B572A5_jpg_No_title_found.txt
# Crawling https://bananasplitfest.com/events/cornhole-tournament/registration/ (49/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_events_cornhole_tournament_registration_Cornhole_Tournament_Registration_Great_A.txt
# Crawling https://bananasplitfest.com/information/event-map (50/50)
# Saved text to text_results/bananasplitfest.com/bananasplitfest.com_information_event_map_Event_Map_Great_American_Banana_Split_Celebration.txt
# Finished crawling bananasplitfest.com, visited 50 pages
# Crawled 50 pages from bananasplitfest.com
#
# Crawl complete!
# Summary of pages crawled:
#   - www.pittsburghsymphony.org: 1 pages
#   - pittsburghopera.org: 50 pages
#   - trustarts.org: 1 pages
#   - carnegiemuseums.org: 50 pages
#   - www.heinzhistorycenter.org: 50 pages
#   - www.thefrickpittsburgh.org: 50 pages
#   - www.visitpittsburgh.com: 50 pages
#   - www.picklesburgh.com: 50 pages
#   - www.pghtacofest.com: 6 pages
#   - pittsburghrestaurantweek.com: 50 pages
#   - littleitalydays.com: 50 pages
#   - bananasplitfest.com: 50 pages
# Results saved to the 'text_results' directory

# %%
# !zip -r music-and-culture-text-data.zip /content/text_results
# Out:
#   adding: content/text_results/ (stored 0%)
#   adding: content/text_results/trustarts.org/ (stored 0%)
#   adding: content/text_results/trustarts.org/trustarts.org_Error.txt (deflated 25%)
#   adding: content/text_results/www.pittsburghsymphony.org/ (stored 0%)
#   adding: content/text_results/www.pittsburghsymphony.org/www.pittsburghsymphony.org_Error.txt (deflated 27%)
#   adding: content/text_results/pittsburghrestaurantweek.com/ (stored 0%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_submit_my_menu_Step_2_Submit_Menu_Pittsburgh_Restaurant_Week.txt (deflated 54%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_pghrestaurantwk_local_food_bloggers_signup_Calling_All_Pittsburgh_Food_.txt (deflated 51%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2022_restaurants_Summer_2022_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2019_restaurants_Summer_2019_Restaurants_Pittsburgh_.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2023_restaurants_Summer_2023_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2017_restaurants_Winter_2017_Restaurants_Pittsburgh_.txt (deflated 48%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_restaurant_roulette_Restaurant_Roulette_Pittsburgh_Restaura.txt (deflated 54%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2020_restaurants_Summer_2020_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_wp_content_uploads_2011_10_SponsorshipLevels_pdf_Error.txt (deflated 46%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_about_About_Pittsburgh_Restaurant_Week.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2013_restaurants_Summer_2013_Restaurants_Pittsburgh_.txt (deflated 54%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2024_restaurants_Winter_2024_Restaurants_Pittsburgh_.txt (deflated 45%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2025_restaurants_Winter_2025_Restaurants_Pittsburgh_.txt (deflated 45%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2014_restaurants_Winter_2014_Restaurants_Pittsburgh_.txt (deflated 46%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_registration_Get_Involved_Pittsburgh_Restaurant_Week.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2020_restaurants_Winter_2020_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_newsletter_Newsletter_Pittsburgh_Restaurant_Week.txt (deflated 38%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2016_restaurants_Summer_2016_Restaurants_Pittsburgh_.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2025_restaurants_bonfire_food_drink_Bonfire_food_dri.txt (deflated 44%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_contact_2_Contact_Pittsburgh_Restaurant_Week_Pittsburgh_Rest.txt (deflated 48%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_Pittsburgh_Restaurant_Week_Putting_Pittsburgh_Rest.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2023_restaurants_Winter_2023_Restaurants_Pittsburgh_.txt (deflated 46%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2025_restaurants_andora_restaurant_Andora_Restaurant.txt (deflated 44%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_Restaurants_Pittsburgh_Restaurant_Week.txt (deflated 67%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_cdn_cgi_l_email_protection_Email_Protection_Cloudflare.txt (deflated 46%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2018_restaurants_Winter_2018_Restaurants_Pittsburgh_.txt (deflated 50%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2022_restaurants_Winter_2022_Restaurants_Pittsburgh_.txt (deflated 42%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2012_restaurants_Winter_2012_Restaurants_Pittsburgh_.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2015_restaurants_Summer_2015_Restaurants_Pittsburgh_.txt (deflated 53%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2017_restaurants_Summer_2017_Restaurants_Pittsburgh_.txt (deflated 43%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2021_restaurants_Winter_2021_Restaurants_Pittsburgh_.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2012_restaurants_Summer_2012_Restaurants_Pittsburgh_.txt (deflated 55%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_wp_content_uploads_2011_10_PRWS14_SponsorshipLevels_Web_pdf_No_title_fo.txt (deflated 31%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2021_restaurants_Summer_2021_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2024_restaurants_Summer_2024_Restaurants_Pittsburgh_.txt (deflated 49%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2015_restaurants_Winter_2015_Restaurants_Pittsburgh_.txt (deflated 52%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_register_Online_Restaurant_Registration_Pittsburgh_Restaura.txt (deflated 56%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_suggest_a_restaurant_Suggest_A_Restaurant_Pittsburgh_Restau.txt (deflated 55%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2016_restaurants_Winter_2016_Restaurants_Pittsburgh_.txt (deflated 50%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_contest_guidelines_Contest_Guidelines_Pittsburgh_Restaurant_Week.txt (deflated 48%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2013_restaurants_Winter_2013_Restaurants_Pittsburgh_.txt (deflated 53%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2014_restaurants_Summer_2014_Restaurants_Pittsburgh_.txt (deflated 55%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_summer_2018_restaurants_Summer_2018_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_sponsor_the_celebration_Sponsor_the_Celebration_Pittsburgh_Restaurant_W.txt (deflated 48%)
#   adding: content/text_results/pittsburghrestaurantweek.com/pittsburghrestaurantweek.com_restaurants_winter_2019_restaurants_Winter_2019_Restaurants_Pittsburgh_.txt (deflated 47%)
#   adding: content/text_results/carnegiemuseums.org/ (stored 0%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_stem_STEM_Archives_Carnegie_Museums_of_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_donate_corporate_gifts_Corporate_Giving_Carnegie_Museums_of_Pittsbu.txt (deflated 58%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_About_Us_Carnegie_Museums_of_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_teen_membership_A_Free_Membership_Just_for_Teens_Carnegi.txt (deflated 56%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_opportunities_Opportunities_Carnegie_Museums_of_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_history_Our_History_Carnegie_Museums_of_Pittsburgh.txt (deflated 56%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt (deflated 46%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_learn_with_us_Learn_With_Us_Carnegie_Museums_of_Pittsburgh.txt (deflated 60%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegieconnectors_Carnegie_Connectors_Carnegie_Museums_of_Pittsburgh.txt (deflated 60%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_current_issue_Winter_2024_Carnegie_Museums_of_Pittsburgh.txt (deflated 63%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt (deflated 49%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_weddings_at_the_museums_Weddings_at_the_Museums_Carnegie_Museums_of_Pittsb.txt (deflated 58%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_access_for_all_Access_for_All_Carnegie_Museums_of_Pittsb.txt (deflated 54%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_where_art_science_meet_Where_Art_Science_Meet_Archives_Carnegie_Museums_o.tx.txt (deflated 57%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_science_nature_Science_Nature_Archives_Carnegie_Museums_of_Pittsb.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_face_time_Facetime_Q_A_Archives_Carnegie_Museums_of_Pittsbur.txt (deflated 60%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_events_Events_Archive_Carnegie_Museums_of_Pittsburgh.txt (deflated 46%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_Carnegie_magazine_Carnegie_Museums_of_Pittsburgh.txt (deflated 50%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_science_center_Carnegie_Science_Center_Carnegie_Museums_of_Pittsb.txt (deflated 54%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_impact_Our_Impact_Carnegie_Museums_of_Pittsburgh.txt (deflated 50%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_faq_Membership_FAQs_Carnegie_Museums_of_Pittsburgh.txt (deflated 64%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_contact_us_Contact_Us_Carnegie_Museums_of_Pittsburgh.txt (deflated 46%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_Join_Support_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_the_inclusive_museum_The_Inclusive_Museum_Archives_Carnegie_Museums_of_.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_members_only_events_Member_Events_Carnegie_Museums_of_Pi.txt (deflated 65%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_carnegie_magazine_archive_Carnegie_magazine_Archive_Carnegie_M.txt (deflated 62%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_advertise_Advertise_Carnegie_Museums_of_Pittsburgh.txt (deflated 47%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_the_andy_warhol_museum_The_Andy_Warhol_Museum_Carnegie_Museums_of_Pittsbu.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_mission_and_core_values_Mission_and_Core_Values_Carnegie_Museums_of_Pittsb.txt (deflated 51%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_view_our_exhibitions_View_Our_Exhibitions_Carnegie_Museums_of_Pitts.txt (deflated 60%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_donate_Support_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_Membership_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_reciprocal_privileges_Reciprocal_Privileges_Carnegie_Mus.txt (deflated 55%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_timed_tickets_Timed_Tickets_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_museums_in_oakland_Carnegie_Museums_in_Oakland_Carnegie_Museums_of_Pi.t.txt (deflated 56%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_plan_a_visit_Plan_a_Visit_Carnegie_Museums_of_Pittsburgh.txt (deflated 59%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_great_event_spaces_Great_Event_Spaces_Carnegie_Museums_of_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_joinrenew_Become_a_Member_Carnegie_Museums_of_Pittsburgh.txt (deflated 57%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_explore_our_collections_Explore_Our_Collections_Carnegie_Museums_of.txt (deflated 58%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_our_museums_Our_Museums_Carnegie_Museums_of_Pittsburgh.txt (deflated 54%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_art_Art_Archives_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_about_us_leadership_Leadership_Carnegie_Museums_of_Pittsburgh.txt (deflated 62%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_carnegie_magazine_subscribe_Subscribe_Carnegie_Museums_of_Pittsburgh.txt (deflated 43%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_carnegie_international_Carnegie_International_Archives_Carnegie_Museums_o.tx.txt (deflated 52%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_behind_scenes_Behind_the_Scenes_Archives_Carnegie_Museums_of_Pit.txt (deflated 50%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_join_support_membership_benefits_Benefits_Carnegie_Museums_of_Pittsburgh.txt (deflated 44%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_tag_community_Community_Archives_Carnegie_Museums_of_Pittsburgh.txt (deflated 48%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_things_to_do_Things_to_Do_Carnegie_Museums_of_Pittsburgh.txt (deflated 45%)
#   adding: content/text_results/carnegiemuseums.org/carnegiemuseums.org_Home_Carnegie_Museums_of_Pittsburgh.txt (deflated 58%)
#   adding: content/text_results/pittsburghopera.org/ (stored 0%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_madama_butterfly_MADAMA_BUTTERFLY_Pittsburgh_Opera.txt (deflated 62%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_adults_Pittsburgh_Opera_Education_Adults_Pittsburgh_Opera.txt (deflated 69%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_special_events_Pittsburgh_Opera_Special_Events_Pittsburgh_Opera.txt (deflated 72%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_mobile_app_Mobile_App_Pittsburgh_Opera.txt (deflated 67%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_resources_Pittsburgh_Opera_Education_Resources_Pittsburgh_Op.txt (deflated 72%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_free_childcare_services_Free_Childcare_Services_Pittsburgh_Opera.txt (deflated 65%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_Home_Pittsburgh_Opera.txt (deflated 79%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_corporate_giving_Corporate_Giving_Pittsburgh_Opera.txt (deflated 71%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_educators_Pittsburgh_Opera_programs_and_resources_for_Educat.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_curlew_river_CURLEW_RIVER_Pittsburgh_Opera.txt (deflated 63%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_falstaff_FALSTAFF_Pittsburgh_Opera.txt (deflated 62%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_ways_to_give_Give_Now_to_Pittsburgh_Opera_Pittsburgh_Opera.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_matching_gift_program_Matching_Gift_Program_Pittsburgh_Opera.txt (deflated 69%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_season_pass_Opus_Pass_Pittsburgh_Opera.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_accessibility_Pittsburgh_Opera_Accessibility_Pittsburgh_Opera.txt (deflated 71%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_free_rideshare_vouchers_Free_Rideshare_Vouchers_Pittsburgh_Opera.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_boheme_LA_BOHEME_Pittsburgh_Opera.txt (deflated 59%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_groups_tickets_Pittsburgh_Opera_Group_Services_Pittsburgh_Opera.txt (deflated 75%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_about_financial_documents_Pittsburgh_Opera_Public_Financial_Documents_Pittsb.txt (deflated 83%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_students_Pittsburgh_Opera_Education_Students_Pittsburgh_Ope.txt (deflated 67%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_Pittsburgh_Opera_2024_25_Season_Pittsburgh_Opera.txt (deflated 78%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_fellow_travelers_FELLOW_TRAVELERS_Pittsburgh_Opera.txt (deflated 61%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_Pittsburgh_Opera_tickets_Pittsburgh_Opera.txt (deflated 76%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_opera_faqs_Pittsburgh_Opera_FAQs_Pittsburgh_Opera.txt (deflated 62%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_give_now_Pittsburgh_Opera_Contributor_Benefits_Pittsburgh_O.txt (deflated 70%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_volunteer_Volunteer_at_Pittsburgh_Opera_Pittsburgh_Opera.txt (deflated 76%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_Support_Pittsburgh_Opera_Pittsburgh_Opera.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_about_operamyths_Opera_Mythbusting_Pittsburgh_Opera.txt (deflated 63%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_government_support_Government_Support_Pittsburgh_Opera.txt (deflated 79%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_give_the_gift_of_opera_Give_the_Gift_of_Opera_Pittsburgh_Opera.txt (deflated 77%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_monteverdi_Monteverdi_Society_Pittsburgh_Opera.txt (deflated 73%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_student_tickets_Student_Tickets_Pittsburgh_Opera.txt (deflated 74%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_about_mission_history_Pittsburgh_Opera_Mission_and_History_Pittsburgh_Op.txt (deflated 65%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_sustaining_giving_Sustaining_Giving_Pittsburgh_Opera.txt (deflated 69%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_schools_Pittsburgh_Opera_Education_Schools_Pittsburgh_Oper.txt (deflated 74%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_families_Pittsburgh_Opera_Education_Families_Pittsburgh_Ope.txt (deflated 75%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_past_seasons_Pittsburgh_Opera_past_seasons_Pittsburgh_Opera.txt (deflated 68%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_calendar_Pittsburgh_Opera_s_Calendar_Pittsburgh_Opera.txt (deflated 84%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_promotions_and_discounts_Promotions_and_Discounts_Pittsburgh_Opera.txt (deflated 74%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_free_low_cost_events_Pittsburgh_Opera_Free_Low_Cost_Events_Pittsburgh_O.t.txt (deflated 73%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_advertise_with_us_Advertise_With_Us_Pittsburgh_Opera.txt (deflated 75%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_about_inclusion_diversity_equity_accessibility_idea_Inclusion_Diversity_Equity_A.txt (deflated 70%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_education_Pittsburgh_Opera_Education_Pittsburgh_Opera.txt (deflated 72%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_about_About_Pittsburgh_Opera_Pittsburgh_Opera.txt (deflated 72%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_subscribe_today_Pittsburgh_Opera_Season_Tickets_Pittsburgh_Opera.txt (deflated 72%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_season_woman_with_eyes_closed_WOMAN_WITH_EYES_CLOSED_Pittsburgh_Opera.txt (deflated 62%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_foundation_support_Foundation_Support_Pittsburgh_Opera.txt (deflated 74%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_tickets_ticket_offices_policies_Pittsburgh_Opera_ticketing_information_and_polic.txt (deflated 64%)
#   adding: content/text_results/pittsburghopera.org/pittsburghopera.org_support_forever_Forever_Campaign_Pittsburgh_Opera.txt (deflated 72%)
#   adding: content/text_results/littleitalydays.com/ (stored 0%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1729_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_07_GolffatherEntryForm_pdf_No_title_found.txt (deflated 31%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_signB_jpg_No_title_found.txt (deflated 33%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_10_2019_Report_to_Community_2_pdf_No_title_found.txt (deflated 31%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_08_2024_LID_Setup_pdf_Error.txt (deflated 41%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_Little_Italy_Days_Italian_Festival.txt (deflated 49%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_20106327_736952729809909_8692393511896291482_n_jpg_No.txt (deflated 30%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_girls2B_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_07_MISS_LITTLE_ITALY_2024_pdf_Error.txt (deflated 42%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_2_jpg_No_title_found.txt (deflated 34%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_community_report_Community_Report_Little_Italy_Days.txt (deflated 48%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_getting_around_Getting_Around_Little_Italy_Days.txt (deflated 53%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_01_2024_Bloomfield_LID_Contract_Bloomfield_Businesses_pd.txt (deflated 34%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_about_us_About_Us_Little_Italy_Days.txt (deflated 48%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2014_02_WesBanco_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1742_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_entertainment_schedule_Entertainment_Schedule_Little_Italy_Days.txt (deflated 55%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_trophyB_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_faq_FAQ_Little_Italy_Days.txt (deflated 48%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1719_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2015_07_highmark_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_07_2019_LID_vendor_map_pdf_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_14088430_574706156034568_6149722159653816399_n_jpg_No.txt (deflated 30%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_13996229_1752240551655398_123428501207492172_o_jpg_No.txt (deflated 30%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1731_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1733_jpg_No_title_found.txt (deflated 60%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1723C_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1735_jpg_No_title_found.txt (deflated 59%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2014_03_BigDaySmall_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_13995538_1752240328322087_1800593659089128617_o_jpg_N.txt (deflated 30%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_trophy2b_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2021_08_porta_john_map_pdf_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_vendor_Vendor_Little_Italy_Days.txt (deflated 34%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2017_07_IMG_1701_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_bloomfield_businesses_Bloomfield_Businesses_Little_Italy_Days.txt (deflated 50%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2024_12_2025_Bloomfield_LID_Contract_Bloomfield_Guests_pdf_No.txt (deflated 33%)
#   adding: content/text_results/littleitalydays.com/littleitalydays.com_wp_content_uploads_2019_07_GolffatherEventOverview_pdf_No_title_found.txt (deflated 32%)
#   adding: content/text_results/www.pghtacofest.com/ (stored 0%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_faqs_FAQs_2024_Taco_Festival_in_Pittsburgh_PA_September.txt (deflated 50%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_about_About_the_2024_Pittsburgh_Taco_Festival_September_.txt (deflated 47%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_privacy_policy_Privacy_Policy.txt (deflated 61%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_map_The_2024_Pittsburgh_Taco_Festival_Map_Saturday_Sep.txt (deflated 34%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_vendors_Pittsburgh_Taco_Festival_Vendors_2024_Taco_Festiva.txt (deflated 39%)
#   adding: content/text_results/www.pghtacofest.com/www.pghtacofest.com_Pittsburgh_Taco_Festival_Saturday_September_14th_2.txt (deflated 41%)
#   adding: content/text_results/bananasplitfest.com/ (stored 0%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_095856_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_5k_banana_run_5K_Banana_Run_Great_American_Banana_Split_Celebrat.txt (deflated 54%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_140837_scaled_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_145556_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_yellow_tie_gala_Yellow_Tie_Gala_Great_American_Banana_Split_Celebr.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_food_Eat_Drink_Great_American_Banana_Split_Celebration.txt (deflated 46%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_Events_Great_American_Banana_Split_Celebration.txt (deflated 50%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_cornhole_tournament_registration_Cornhole_Tournament_Registration_Great_A.txt (deflated 50%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_schedule_Schedule_Great_American_Banana_Split_Celebration.txt (deflated 48%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_car_show_Car_Show_Great_American_Banana_Split_Celebration.txt (deflated 48%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_participating_vendors_Participating_Vendors_Great_American_Banana_Spl.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_The_Great_American_Banana_Split_Celebration.txt (deflated 53%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_cornhole_tournament_Cornhole_Tournament_Great_American_Banana_Split_Ce.tx.txt (deflated 59%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_vendors_Vendors_Great_American_Banana_Split_Celebration.txt (deflated 48%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_entertainment_Entertainment_Great_American_Banana_Split_Celebrat.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_095856_1_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_crafts_games_activities_Crafts_Games_Activities_Great_American_Banana.txt (deflated 48%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_Activities_Great_American_Banana_Split_Celebration.txt (deflated 52%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_plan_your_visit_Plan_Your_Visit_Great_American_Banana_Split_Celebr.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_information_plan_your_visit_Plan_Your_Visit_Great_American_Banana_Split_Celebr.t.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_volunteer_Volunteer_Great_American_Banana_Split_Celebration.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_Pageant_1_jpg_No_title_found.txt (deflated 60%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_sponsorship_opportunities_Sponsorship_Opportunities_Great_American_Banana_Sp.txt (deflated 56%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_information_media_Media_Great_American_Banana_Split_Celebration.txt (deflated 61%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_history_History_Great_American_Banana_Split_Celebration.txt (deflated 55%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_blood_drive_Blood_Drive_Great_American_Banana_Split_Celebratio.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_entertainment_entertainer_interest_form_Entertainer_Interest_Form_Gre.txt (deflated 51%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant11_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant3_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_information_Information_Great_American_Banana_Split_Celebratio.txt (deflated 48%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_princess_pageant_Banana_Split_Princess_Great_American_Banana_Split_.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240824_185402_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_D9B572A5_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_information_event_map_Event_Map_Great_American_Banana_Split_Celebration.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_information_parking_Parking_Great_American_Banana_Split_Celebration.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240824_190104_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_entertainment_Entertainment_Great_American_Banana_Split_Celebrat.txt (deflated 49%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_143534_scaled_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant10_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_activities_over_21_area_Over_21_Area_Great_American_Banana_Split_Celebrati.txt (deflated 47%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_08_20240825_140832_scaled_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_wp_content_uploads_2024_05_pageant1_jpg_No_title_found.txt (deflated 32%)
#   adding: content/text_results/bananasplitfest.com/bananasplitfest.com_events_banana_challenge_Dole_Great_American_Banana_Challenge_Great_America.txt (deflated 50%)
#   adding: content/text_results/www.thefrickpittsburgh.org/ (stored 0%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Guided_Evening_Tour_of_Kara_Walker_Harpers_Pictorial_History_of_the.txt (deflated 68%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_The_Frick_Art_Museum_Permanent_Collection_The_Frick_Pittsburgh_Muse.txt (deflated 61%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_tours_Tours_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 55%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_donate_Donate_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 54%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Signature_Clayton_Tour_Experience_Gilded_Not_Golden_Clayton_Guided_.txt (deflated 57%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_staff_Staff_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_groupvisits_Group_Visits_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 60%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_equity_Equity_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 56%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_eitc_EITC_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 57%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Book_Talk_Dr_Edda_Fields_Black_on_Harriet_Tubman_and_the_Combahee_R.txt (deflated 64%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Gallery_Conversations_in_Kara_Walker_Harpers_Pictorial_History_of_t.txt (deflated 66%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_see_and_do_See_and_Do_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 65%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_cafe_The_Cafe_at_the_Frick_The_Frick_Pittsburgh_Museums.txt (deflated 55%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Car_and_Carriage_Museum_Car_and_Carriage_Museum_The_Frick_Pittsburg.txt (deflated 61%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_plan_your_visit_Plan_Your_Visit_The_Frick_Pittsburgh_Museums_Garde.txt (deflated 57%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_learn_Learning_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 57%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_rentals_Rental_Events_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 55%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_reciprocal_museums_Reciprocal_Museums_The_Frick_Pittsburgh_Museums_Ga.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_virtual_Virtual_Experiences_The_Frick_Pittsburgh_Museums_G.txt (deflated 56%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_stories_Stories_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 65%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_membership_Membership_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 61%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_calendar_Calendar_of_Events_The_Frick_Pittsburgh_Museums_Ga.txt (deflated 65%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_virtualexhibitions_Virtual_Exhibitions_The_Frick_Pittsburgh_Museums_G.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_The_Art_of_the_Crucifixion_From_Anguish_to_Absurdity_The_Art_of_the.txt (deflated 56%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_accessibility_Accessibility_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 60%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Home_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 60%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_support_Support_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_gifts_of_stock_Gifts_of_Stock_The_Frick_Pittsburgh_Museums_Garden.txt (deflated 53%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_the_frick_societies_The_Frick_Societies_The_Frick_Pittsburgh_Museums_G.tx.txt (deflated 55%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Guest_Label_Writers_in_Conversation_Guest_Label_Writers_in_Conversa.txt (deflated 66%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Duquesne_SoundWalk_at_the_Frick_Duquesne_SoundWalk_at_the_Frick_The.txt (deflated 63%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_oursupporters_Our_Supporters_The_Frick_Pittsburgh_Museums_Garden.txt (deflated 59%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Files_Admin_TheFrickPittsburghSiteMap2022_pdf_No_title_found.txt (deflated 33%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Event_Echoes_An_Evening_of_Music_with_KEA_Echoes_An_Evening_of_Music_with.txt (deflated 55%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_collection_Collection_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 56%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_LegacyPlanning_Legacy_Planning_The_Frick_Pittsburgh_Museums_Garde.txt (deflated 57%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_exhibitions_Exhibitions_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 68%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_store_Store_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 56%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Exhibition_Kara_Walker_Harpers_Pictorial_History_of_the_Civil_War_Annotat.txt (deflated 65%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_corporate_giving_Corporate_Giving_The_Frick_Pittsburgh_Museums_Gard.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_Qualified_Charitable_Distributions_Qualified_Charitable_Distributions_The.txt (deflated 58%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_past_exhibitions_Past_Exhibitions_The_Frick_Pittsburgh_Museums_Gard.txt (deflated 69%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_tickets_Tickets_The_Frick_Pittsburgh_Museums_Gardens.txt (deflated 54%)
#   adding: content/text_results/www.thefrickpittsburgh.org/www.thefrickpittsburgh.org_carandcarriagemuseum_Car_and_Carriage_Museum_The_Frick_Pittsburgh_Museu.t.txt (deflated 58%)
#   adding: content/text_results/www.picklesburgh.com/ (stored 0%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_festival_schedule_lil_gherkins_activity_area_Li_l_Gherkins_KidsPlay_Activity_Ar.txt (deflated 49%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image5_2023_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2024_07_SaturdayLayers_1_jpg_No_title_found.txt (deflated 30%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_cloudy_with_a_chance_of_pickles_Cloudy_with_a_chance_of_pickles_Picklesburgh.tx.txt (deflated 43%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image11_2023_jpg_No_title_found.txt (deflated 30%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_festival_schedule_Festival_Schedules_Picklesburgh.txt (deflated 46%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2024_07_Stanwix_png_No_title_found.txt (deflated 31%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_vendors_Vendors_Picklesburgh.txt (deflated 43%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2024_07_MiniMap2024_png_No_title_found.txt (deflated 32%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_accessibility_Accessibility_Picklesburgh.txt (deflated 50%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image10_2023_jpg_No_title_found.txt (deflated 30%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_three_time_champ_picklesburgh_nominated_again_for_best_specialty_food_festival_.txt (deflated 50%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image7_2023_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_entertainment_Entertainment_Picklesburgh.txt (deflated 57%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2024_07_2024LogoSoup_png_No_title_found.txt (deflated 32%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image2_2023_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image3_2023_jpg_No_title_found.txt (deflated 31%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image13_2023_jpg_No_title_found.txt (deflated 30%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_visit_getting_here_Getting_Here_Picklesburgh.txt (deflated 49%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_visit_Visit_Picklesburgh.txt (deflated 48%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_get_involved_Get_Involved_Picklesburgh.txt (deflated 46%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2018_05_image8_2023_jpg_No_title_found.txt (deflated 59%)
#   adding: content/text_results/www.picklesburgh.com/www.picklesburgh.com_wp_content_uploads_2024_06_pittsburgh_pickle_logo_jpeg_No_title_found.txt (deflated 33%)
# ...
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_scout_programs_Scout_Programs_Heinz_History_Center.txt (deflated 54%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_Research_Heinz_History_Center.txt (deflated 58%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_america_101_America_101_Heinz_History_Center.txt (deflated 54%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_work_with_us_Work_With_Us_Heinz_History_Center.txt (deflated 65%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_american_girlhood_a_window_into_history_American_Girlhood_A_Window_.txt (deflated 51%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_african_american_program_African_American_Program_Heinz_History_.txt (deflated 56%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_publications_Publications_Heinz_History_Center.txt (deflated 52%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_fort_pitt_Fort_Pitt_Museum_Heinz_History_Center.txt (deflated 47%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_vietnam_veterans_day_50th_anniversary_commemoration_2025_Vietnam_Ve.txt (deflated 51%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_families_Kids_Families_Heinz_History_Center.txt (deflated 50%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_sitemap_Sitemap_Heinz_History_Center.txt (deflated 67%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_What_s_On_Heinz_History_Center.txt (deflated 56%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_Home_Heinz_History_Center.txt (deflated 61%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_meadowcroft_Meadowcroft_Rockshelter_and_Historic_Village_Heinz.txt (deflated 58%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_planned_giving_Planned_Giving_Heinz_History_Center.txt (deflated 48%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_sports_museum_Western_Pennsylvania_Sports_Museum_Heinz_History_C.txt (deflated 66%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_contact_us_Contact_Us_Heinz_History_Center.txt (deflated 58%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_education_For_Schools_Teachers_Heinz_History_Center.txt (deflated 55%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_explore_Explore_Our_Collections_Heinz_History_Center.txt (deflated 57%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_spring_educator_open_house_Spring_Educator_Open_House_Heinz_History.txt (deflated 50%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_vintage_pittsburgh_2025_Vintage_Pittsburgh_Heinz_History_Center.txt (deflated 47%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_events_Events_for_March_2025_Heinz_History_Center.txt (deflated 56%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_exhibits_Exhibits_Heinz_History_Center.txt (deflated 54%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_Join_Give_Heinz_History_Center.txt (deflated 51%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_italian_american_program_Italian_American_Program_Heinz_History_.txt (deflated 57%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_commemorative_gifts_Commemorative_Gifts_Heinz_History_Center.txt (deflated 55%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_blog_Blog_Posts_Archive_Heinz_History_Center.txt (deflated 47%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_event_rentals_Event_Rentals_Heinz_History_Center.txt (deflated 51%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_sports_museum_Western_Pennsylvania_Sports_Museum_Heinz_History_C.tx.txt (deflated 54%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_search_Search_Heinz_History_Center.txt (deflated 46%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_virtual_tours_Virtual_Tours_Heinz_History_Center.txt (deflated 53%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_history_center_Heinz_History_Center_Heinz_History_Center.txt (deflated 65%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_detre_library_archives_Detre_Library_Archives_Heinz_History_Cent.txt (deflated 52%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_make_a_donation_Make_a_Donation_Heinz_History_Center.txt (deflated 55%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_policies_Policies_Heinz_History_Center.txt (deflated 64%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_event_national_history_day_pittsburgh_03152025_National_History_Day_Pitts.txt (deflated 51%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_whats_on_meadowcroft_Meadowcroft_Rockshelter_and_Historic_Village_Heinz.t.txt (deflated 68%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_health_safety_Health_Safety_Heinz_History_Center.txt (deflated 45%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_visit_heinz_history_center_Heinz_History_Center_Heinz_History_Center.txt (deflated 54%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_learn_Learn_Heinz_History_Center.txt (deflated 52%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_cdn_cgi_l_email_protection_Email_Protection_Cloudflare.txt (deflated 46%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_rauh_jewish_history_program_archives_Rauh_Jewish_History_Program.txt (deflated 60%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_research_contribute_to_our_collections_Contribute_to_Our_Collections_Hein.txt (deflated 60%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_join_Become_a_Member_Heinz_History_Center.txt (deflated 53%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_give_fundraising_events_Fundraising_Events_Heinz_History_Center.txt (deflated 53%)
#   adding: content/text_results/www.heinzhistorycenter.org/www.heinzhistorycenter.org_about_About_Heinz_History_Center.txt (deflated 58%)
#   adding: content/text_results/www.visitpittsburgh.com/ (stored 0%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_Fun_Things_to_Do_in_Pittsburgh_Visit_Pittsburgh.txt (deflated 50%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_college_visits_Planning_College_Visits_to_Pittsburgh_Campus_T.txt (deflated 45%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_reasons_to_meet_in_pittsburgh_Meet_in_Pittsburgh_Visit_P.txt (deflated 53%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_submit_your_event_Submit_an_Event_Visit_Pittsburgh_Visit_Pi.txt (deflated 41%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_beyond_pittsburgh_Beyond_Pittsburgh_Visit_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_Meet_in_Pittsburgh_Pittsburgh_s_Business_Events_Te.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_annual_events_Annual_Events_in_Pittsburgh_PA_2025_Festivals.txt (deflated 58%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_request_for_proposal_Pittsburgh_PA_Meeting_Planning_Subm.txt (deflated 41%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_lgbtq_travel_LGBTQIA_Travel_in_Pittsburgh_Travel_Tips_and_Inf.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_tours_sightseeing_Pittsburgh_Sightseeing_Tours_Visit_Pittsburgh.txt (deflated 49%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_casinos_gaming_Pittsburgh_Casinos_Gaming_Reviews_Maps_Photos_Vi.txt (deflated 40%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_health_wellness_Health_Wellness_in_Pittsburgh_Directory_and_Map.txt (deflated 45%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_restaurants_culinary_wineries_distilleries_Pittsburgh_Distilleries_Wineries_.txt (deflated 54%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_hotels_resorts_Top_Hotels_Resorts_in_Pittsburgh_Visit_Pittsburgh.txt (deflated 51%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_this_week_in_pittsburgh_Things_to_do_in_Pittsburgh_This_Wee.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_outdoor_adventure_Outdoor_Recreation_in_Pittsburgh_Golf_Trails_.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_explore_black_culture_heritage_Explore_Black_Culture_Heritage.txt (deflated 49%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_restaurants_culinary_farms_farmers_markets_Pittsburgh_Farmers_Markets_U_Pick.txt (deflated 51%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_Visit_Pittsburgh_Official_Tourism_Site_for_Pittsbu.txt (deflated 49%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_visitors_guide_Official_Pittsburgh_Travel_Guide_Visit_Pittsbu.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_weather_Pittsburgh_Climate_and_Average_Weather_by_Month_Vi.tx.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_the_pittsburgh_pass_The_Pittsburgh_Pass_Visit_Pittsburgh.txt (deflated 53%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_transportation_Pittsburgh_Transportation_Getting_Around_Visit.txt (deflated 48%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_senior_travel_Senior_Travel_Visit_Pittsburgh.txt (deflated 52%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_food_festivals_Pittsburgh_Food_Festivals_Greek_Oktoberfest_.txt (deflated 58%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_newsletter_signup_Sign_Up_For_Pittsburgh_s_Newsletter_Tips_In.txt (deflated 39%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_arts_culture_Arts_Culture_Visit_Pittsburgh.txt (deflated 50%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_family_fun_Things_to_do_in_Pittsburgh_with_Kids_Visit_Pittsbu.t.txt (deflated 51%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_hotels_Hotels_Visit_Pittsburgh.txt (deflated 42%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_group_tour_Group_Tours_Meeting_Planning_Plan_Pittsburgh_.txt (deflated 45%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_shopping_Shopping_in_Pittsburgh_Reviews_Maps_Coupons_Visit_.txt (deflated 47%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_free_things_to_do_Free_Things_to_Do_in_Pittsburgh_Today_Visit_P.txt (deflated 56%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_halloween_events_2024_Halloween_Activities_Events_in_Pittsb.txt (deflated 55%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_marathons_runs_walks_Pittsburgh_Marathons_Runs_and_Walks_Ou.txt (deflated 54%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_pet_friendly_travel_Pet_friendly_Travel_Visit_Pittsburgh.txt (deflated 54%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_itinerary_Saved_Items_Visit_Pittsburgh.txt (deflated 39%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_restaurants_culinary_craft_breweries_The_Best_Pittsburgh_Breweries_Visit_Pit.txt (deflated 57%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_meeting_planner_toolkit_Marketing_Toolkit_Visit_Pittsbur.txt (deflated 46%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_welcome_centers_Official_Pittsburgh_Visitors_Centers_Visit_Pi.txt (deflated 48%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_Pittsburgh_Trip_Planning_Maps_Weather_Visitors_Gui.txt (deflated 51%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_things_to_do_pittsburgh_sports_teams_Pittsburgh_PA_Sports_Teams_Steelers_Pir.txt (deflated 56%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_holidays_Pittsburgh_Christmas_Events_2024_Visit_Pittsburgh..txt (deflated 59%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_neighborhoods_Pittsburgh_Neighborhoods_Map_Visit_Pittsburgh_Visi.txt (deflated 55%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_medical_travel_Medical_Travel_to_Pittsburgh_PA_Visit_Pittsbur.txt (deflated 44%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_restaurants_culinary_bars_nightlife_Pittsburgh_Bars_Nightlife_Casinos_Restau.txt (deflated 50%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_restaurants_culinary_Pittsburgh_Restaurants_Listings_Nightlife_Farmers_.txt (deflated 53%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_plan_your_trip_accessibility_guide_The_Pittsburgh_Accessibility_Guide_Inform.txt (deflated 60%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_film_festivals_Film_Festivals_in_Pittsburgh_Pittsburgh_Annu.txt (deflated 59%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_meetings_and_events_event_services_Pittsburgh_PA_Destination_Services_Pittsb.txt (deflated 56%)
#   adding: content/text_results/www.visitpittsburgh.com/www.visitpittsburgh.com_events_festivals_Pittsburgh_Events_Festivals_Visit_Pittsburgh.txt (deflated 49%)

# %%
import json

# %%
def extract_content_with_headings(json_file_path, output_text_file):
    """
    Extract content with headings from a JSON file and save as a structured text corpus
    """
    # Load the JSON data
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Extract paragraphs and headings
    paragraphs = data.get('paragraphs', [])
    headings = data.get('headings', [])

    # Sort headings and paragraphs in a combined list
    # This is a simplified approach - in reality you'd need to determine
    # the actual position of each element in the original HTML

    # Create the corpus text
    corpus = ""

    # Add title as first line
    if data.get('title'):
        corpus += data['title'] + "\n\n"

    # Add each paragraph, with headings inserted where appropriate
    # This is a simplified version that just intersperses headings
    heading_index = 0
    for i, paragraph in enumerate(paragraphs):
        # Insert a heading every few paragraphs if available
        if heading_index < len(headings) and i % 3 == 0:
            heading = headings[heading_index]
            corpus += f"# {heading['text']}\n\n"
            heading_index += 1

        # Add the paragraph
        if paragraph and len(paragraph) > 15:
            corpus += paragraph + "\n\n"

    # Write to the output file
    with open(output_text_file, 'w', encoding='utf-8') as f:
        f.write(corpus)

    print(f"Extracted content with {len(headings)} headings and {len(paragraphs)} paragraphs")
    print(f"Saved to {output_text_file}")

# %%
# Example usage
if __name__ == "__main__":
    json_file = "page_content.json"  # Path to your JSON file
    output_file = "corpus.txt"  # Path to save the text corpus
    extract_content_with_headings(json_file, output_file)
# Out:
# Extracted content with 4 headings and 12 paragraphs
# Saved to corpus.txt

# %%
import requests
from bs4 import BeautifulSoup
import json

def extract_and_append_to_corpus(url, corpus_file_path):
    """
    Extract content from a URL and append it to an existing corpus file

    Args:
        url (str): The URL of the page to scrape
        corpus_file_path (str): Path to the existing corpus file
    """
    # Send request to the URL
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise exception for bad status codes
    except Exception as e:
        print(f"Error fetching the URL: {e}")
        return

    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract page title
    title = soup.title.text.strip() if soup.title else "No title found"

    # Extract all paragraphs
    paragraphs = [p.text.strip() for p in soup.find_all('p') if p.text.strip() and len(p.text.strip()) > 15]

    # Prepare content to append
    new_content = f"\n\n=== {title} ===\n\n"
    for paragraph in paragraphs:
        new_content += paragraph + "\n\n"

    # Append to existing corpus file
    try:
        with open(corpus_file_path, 'a', encoding='utf-8') as f:
            f.write(new_content)

        print(f"Added {len(paragraphs)} paragraphs from '{title}'")
        print(f"Added {len(new_content)} characters to {corpus_file_path}")
    except Exception as e:
        print(f"Error appending to corpus file: {e}")

# Example usage
if __name__ == "__main__":
    url = input("Enter a URL to extract content from: ")
    corpus_file = "corpus.txt"  # Path to your existing corpus file
    extract_and_append_to_corpus(url, corpus_file)
# Out:
# Enter a URL to extract content from: https://en.wikipedia.org/wiki/History_of_Pittsburgh
# Added 88 paragraphs from 'History of Pittsburgh - Wikipedia'
# Added 50444 characters to corpus.txt

# %%
import requests
from bs4 import BeautifulSoup
import json

def extract_page_content(url):
    """
    Extract all text content from a web page using Beautiful Soup

    Args:
        url (str): The URL of the page to scrape

    Returns:
        dict: Dictionary containing the page title, paragraphs, and headings
    """
    # Send request to the URL
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise exception for bad status codes

    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract page title
    title = soup.title.text.strip() if soup.title else "No title found"

    # Extract all paragraphs
    paragraphs = [p.text.strip() for p in soup.find_all('p') if p.text.strip()]

    # Extract all headings
    headings = []
    for tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        for heading in soup.find_all(tag):
            if heading.text.strip():
                headings.append({
                    'level': tag,
                    'text': heading.text.strip()
                })

    # Extract all links
    links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        text = link.text.strip()
        if href and text:
            links.append({
                'text': text,
                'url': href
            })

    # Compile the results
    result = {
        'url': url,
        'title': title,
        'headings': headings,
        'paragraphs': paragraphs,
        'links': links
    }

    return result

# Example usage
if __name__ == "__main__":
    url = input("Enter a URL to scrape: ")
    content = extract_page_content(url)

    # Print summary
    print(f"\nTitle: {content['title']}")
    print(f"Found {len(content['paragraphs'])} paragraphs")
    print(f"Found {len(content['headings'])} headings")
    print(f"Found {len(content['links'])} links")

    # Save the data to a JSON file
    with open('page_content.json', 'w', encoding='utf-8') as f:
        json.dump(content, f, indent=4, ensure_ascii=False)

    print("\nData saved to page_content.json")
# Out:
# Enter a URL to scrape: https://www.britannica.com/place/Pittsburgh
#
# Title: Pittsburgh | Location, History, Teams, Attractions, & Facts | Britannica
# Found 10 paragraphs
# Found 4 headings
# Found 168 links
#
# Data saved to page_content.json

# %%
import requests
from bs4 import BeautifulSoup
import json

def extract_page_content(url):
    """
    Extract all text content from a web page using Beautiful Soup

    Args:
        url (str): The URL of the page to scrape

    Returns:
        dict: Dictionary containing the page title, paragraphs, and headings
    """
    # Send request to the URL
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise exception for bad status codes

    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract page title
    title = soup.title.text.strip() if soup.title else "No title found"

    # Extract all paragraphs
    paragraphs = [p.text.strip() for p in soup.find_all('p') if p.text.strip()]

    # Extract all headings
    headings = []
    for tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        for heading in soup.find_all(tag):
            if heading.text.strip():
                headings.append({
                    'level': tag,
                    'text': heading.text.strip()
                })

    # Extract all links
    links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        text = link.text.strip()
        if href and text:
            links.append({
                'text': text,
                'url': href
            })

    # Compile the results
    result = {
        'url': url,
        'title': title,
        'headings': headings,
        'paragraphs': paragraphs,
        'links': links
    }

    return result

def preview_corpus_content(content, max_paragraphs=5):
    """
    Generate a preview of the content that would be added to the corpus

    Args:
        content (dict): The extracted content dictionary
        max_paragraphs (int): Maximum number of paragraphs to show in preview

    Returns:
        str: Formatted preview text
    """
    preview = f"\n=== {content['title']} ===\n\n"

    # Add first few paragraphs
    paragraphs_to_show = min(max_paragraphs, len(content['paragraphs']))
    for i in range(paragraphs_to_show):
        preview += content['paragraphs'][i] + "\n\n"

    # Add indication if there are more paragraphs
    if len(content['paragraphs']) > max_paragraphs:
        preview += f"[...and {len(content['paragraphs']) - max_paragraphs} more paragraphs...]\n"

    return preview

def add_to_corpus(content, corpus_file, append=True):
    """
    Add content to corpus file

    Args:
        content (dict): The extracted content dictionary
        corpus_file (str): Path to corpus file
        append (bool): Whether to append or overwrite
    """
    mode = 'a' if append else 'w'

    corpus_text = f"\n\n=== {content['title']} ===\n\n"
    for paragraph in content['paragraphs']:
        if paragraph and len(paragraph) > 15:  # Skip very short paragraphs
            corpus_text += paragraph + "\n\n"

    with open(corpus_file, mode, encoding='utf-8') as f:
        f.write(corpus_text)

    print(f"{'Added to' if append else 'Created'} corpus file: {corpus_file}")
    print(f"Added {len(content['paragraphs'])} paragraphs, {len(corpus_text)} characters")

# Example usage
if __name__ == "__main__":
    url = input("Enter a URL to scrape: ")
    content = extract_page_content(url)

    # Print summary
    print(f"\nTitle: {content['title']}")
    print(f"Found {len(content['paragraphs'])} paragraphs")
    print(f"Found {len(content['headings'])} headings")
    print(f"Found {len(content['links'])} links")

    # Preview the content
    preview = preview_corpus_content(content)
    print("\nPREVIEW OF CONTENT TO ADD:")
    print("-" * 50)
    print(preview)
    print("-" * 50)

    # Save the data to a JSON file
    with open('page_content.json', 'w', encoding='utf-8') as f:
        json.dump(content, f, indent=4, ensure_ascii=False)
    print("\nData saved to page_content.json")

    # Ask user if they want to add to corpus
    corpus_file = "corpus.txt"
    add_choice = input(f"\nDo you want to add this content to {corpus_file}? (y/n): ").lower()

    if add_choice == 'y':
        # Check if corpus file exists
        import os
        file_exists = os.path.isfile(corpus_file)

        if file_exists:
            append_choice = input(f"{corpus_file} already exists. Append to it? (y/n): ").lower()
            append = append_choice == 'y'
        else:
            append = False

        add_to_corpus(content, corpus_file, append)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2cf3607bf9c9> in <cell line: 0>()
#     109 # Example usage
#     110 if __name__ == "__main__":
# --> 111     url = input("Enter a URL to scrape: ")
#     112     content = extract_page_content(url)
#     113
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
import PyPDF2
import io  # For handling in-memory binary data

def extract_page_content(url):
    """Extract all text content from a web page using Beautiful Soup"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.title.text.strip() if soup.title else "No title found"
    paragraphs = [p.text.strip() for p in soup.find_all('p') if p.text.strip()]

    # Extract all headings
    headings = []
    for tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        for heading in soup.find_all(tag):
            if heading.text.strip():
                headings.append({
                    'level': tag,
                    'text': heading.text.strip()
                })

    # Extract all links
    links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        text = link.text.strip()
        if href and text:
            links.append({
                'text': text,
                'url': href
            })

    result = {
        'source_type': 'web',
        'url': url,
        'title': title,
        'headings': headings,
        'paragraphs': paragraphs,
        'links': links
    }

    return result

def extract_pdf_content(pdf_path_or_url):
    """Extract text content from a PDF file using PyPDF2"""
    is_url = pdf_path_or_url.startswith(('http://', 'https://'))

    try:
        if is_url:
            print(f"Downloading PDF from URL: {pdf_path_or_url}")
            response = requests.get(pdf_path_or_url)
            response.raise_for_status()  # Ensure we got a successful response

            # Get the filename from the URL
            title = pdf_path_or_url.split('/')[-1]

            # Create an in-memory binary stream
            pdf_file = io.BytesIO(response.content)

        else:  # Local file
            if not os.path.exists(pdf_path_or_url):
                print(f"Error: PDF file not found at {pdf_path_or_url}")
                return None

            title = os.path.basename(pdf_path_or_url)
            pdf_file = open(pdf_path_or_url, 'rb')

        # Process the PDF
        reader = PyPDF2.PdfReader(pdf_file)
        print(f"PDF has {len(reader.pages)} pages")

        paragraphs = []
        for page_num in range(len(reader.pages)):
            text = reader.pages[page_num].extract_text()
            if text:
                # Split text into paragraphs based on newlines
                page_paragraphs = [p.strip() for p in text.split('\n') if p.strip()]
                paragraphs.extend(page_paragraphs)

        # Close the file if it's a local file
        if not is_url:
            pdf_file.close()

        print(f"Extracted {len(paragraphs)} text segments from PDF")

        # Clean up paragraphs - remove very short ones, merge related segments
        cleaned_paragraphs = []
        current_paragraph = ""

        for p in paragraphs:
            # Skip likely header/footer patterns, page numbers, etc.
            if len(p) < 20 or p.isdigit():
                continue

            # If it ends with a sentence-ending punctuation, it's a complete thought
            if p.endswith('.') or p.endswith('?') or p.endswith('!'):
                if current_paragraph:
                    current_paragraph += " " + p
                    cleaned_paragraphs.append(current_paragraph)
                    current_paragraph = ""
                else:
                    cleaned_paragraphs.append(p)
            else:
                # It's a partial paragraph or segment, accumulate it
                if current_paragraph:
                    current_paragraph += " " + p
                else:
                    current_paragraph = p

        # Don't forget any remaining text
        if current_paragraph:
            cleaned_paragraphs.append(current_paragraph)

    except Exception as e:
        print(f"Error extracting PDF content: {e}")
        return None

    result = {
        'source_type': 'pdf',
        'file_path': pdf_path_or_url,
        'title': title,
        'paragraphs': cleaned_paragraphs
    }

    return result

def preview_content(content, max_paragraphs=5):
    """Generate a preview of the content that would be added to the corpus"""
    if content['source_type'] == 'web':
        preview = f"\n=== {content['title']} (Web) ===\n\n"
    else:  # PDF
        preview = f"\n=== {content['title']} (PDF) ===\n\n"

    # Add first few paragraphs
    paragraphs_to_show = min(max_paragraphs, len(content['paragraphs']))
    for i in range(paragraphs_to_show):
        preview += content['paragraphs'][i] + "\n\n"

    # Add indication if there are more paragraphs
    if len(content['paragraphs']) > max_paragraphs:
        preview += f"[...and {len(content['paragraphs']) - max_paragraphs} more paragraphs...]\n"

    return preview

def add_to_corpus(content, corpus_file, append=True):
    """Add content to corpus file"""
    mode = 'a' if append else 'w'

    if content['source_type'] == 'web':
        corpus_text = f"\n\n=== {content['title']} (Web: {content['url']}) ===\n\n"
    else:  # PDF
        corpus_text = f"\n\n=== {content['title']} (PDF) ===\n\n"

    for paragraph in content['paragraphs']:
        if paragraph and len(paragraph) > 20:  # Skip very short paragraphs
            corpus_text += paragraph + "\n\n"

    with open(corpus_file, mode, encoding='utf-8') as f:
        f.write(corpus_text)

    print(f"{'Added to' if append else 'Created'} corpus file: {corpus_file}")
    print(f"Added {len(content['paragraphs'])} paragraphs, {len(corpus_text)} characters")

# Example usage
if __name__ == "__main__":
    corpus_file = "corpus.txt"

    # Ask user for source type
    source_type = input("Extract from [1] Website or [2] PDF? (Enter 1 or 2): ").strip()

    if source_type == '1':
        # Extract from website
        url = input("Enter a URL to scrape: ")
        content = extract_page_content(url)
    elif source_type == '2':
        # Extract from PDF
        pdf_path_or_url = input("Enter the path or URL to your PDF file: ")
        content = extract_pdf_content(pdf_path_or_url)
        if not content:
            print("Failed to extract content from PDF. Exiting.")
            exit()
    else:
        print("Invalid option. Exiting.")
        exit()

    # Print summary
    print(f"\nSource: {content['title']}")
    print(f"Found {len(content['paragraphs'])} paragraphs")

    # Preview the content
    preview = preview_content(content)
    print("\nPREVIEW OF CONTENT TO ADD:")
    print("-" * 50)
    print(preview)
    print("-" * 50)

    # Ask user if they want to add to corpus
    add_choice = input(f"\nDo you want to add this content to {corpus_file}? (y/n): ").lower()

    if add_choice == 'y':
        # Check if corpus file exists
        file_exists = os.path.isfile(corpus_file)

        if file_exists:
            append_choice = input(f"{corpus_file} already exists. Append to it? (y/n): ").lower()
            append = append_choice == 'y'
        else:
            append = False

        add_to_corpus(content, corpus_file, append)

    # Save the raw extraction data to a JSON file
    if content['source_type'] == 'web':
        output_file = 'page_content.json'
    else:
        output_file = 'pdf_content.json'

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(content, f, indent=4, ensure_ascii=False)
    print(f"\nRaw extraction data saved to {output_file}")
# Out:
# Extract from [1] Website or [2] PDF? (Enter 1 or 2): 2
# Enter the path or URL to your PDF file: https://apps.pittsburghpa.gov/redtail/images/23255_2024_Operating_Budget.pdf
# Downloading PDF from URL: https://apps.pittsburghpa.gov/redtail/images/23255_2024_Operating_Budget.pdf
# Error extracting PDF content: HTTPSConnectionPool(host='apps.pittsburghpa.gov', port=443): Max retries exceeded with url: /redtail/images/23255_2024_Operating_Budget.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Failed to extract content from PDF. Exiting.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-aabb15d22a05> in <cell line: 0>()
#     193
#     194     # Print summary
# --> 195     print(f"\nSource: {content['title']}")
#     196     print(f"Found {len(content['paragraphs'])} paragraphs")
#     197
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
import PyPDF2
import io  # For handling in-memory binary data

def extract_page_content(url, verify_ssl=True):
    """Extract all text content from a web page using Beautiful Soup"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    try:
        response = requests.get(url, headers=headers, verify=verify_ssl)
        response.raise_for_status()
    except requests.exceptions.SSLError as e:
        if verify_ssl:
            print("SSL verification failed. Trying again without verification...")
            return extract_page_content(url, verify_ssl=False)
        else:
            print(f"Error fetching URL: {e}")
            return None
    except Exception as e:
        print(f"Error fetching URL: {e}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.title.text.strip() if soup.title else "No title found"
    paragraphs = [p.text.strip() for p in soup.find_all('p') if p.text.strip()]

    # Extract all headings
    headings = []
    for tag in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        for heading in soup.find_all(tag):
            if heading.text.strip():
                headings.append({
                    'level': tag,
                    'text': heading.text.strip()
                })

    # Extract all links
    links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        text = link.text.strip()
        if href and text:
            links.append({
                'text': text,
                'url': href
            })

    result = {
        'source_type': 'web',
        'url': url,
        'title': title,
        'headings': headings,
        'paragraphs': paragraphs,
        'links': links
    }

    return result

def extract_pdf_content(pdf_path_or_url, verify_ssl=True):
    """Extract text content from a PDF file using PyPDF2"""
    is_url = pdf_path_or_url.startswith(('http://', 'https://'))

    try:
        if is_url:
            print(f"Downloading PDF from URL: {pdf_path_or_url}")
            try:
                response = requests.get(pdf_path_or_url, verify=verify_ssl)
                response.raise_for_status()  # Ensure we got a successful response
            except requests.exceptions.SSLError as e:
                if verify_ssl:
                    print("SSL verification failed. Trying again without verification...")
                    return extract_pdf_content(pdf_path_or_url, verify_ssl=False)
                else:
                    raise e

            # Get the filename from the URL
            title = pdf_path_or_url.split('/')[-1]

            # Create an in-memory binary stream
            pdf_file = io.BytesIO(response.content)

        else:  # Local file
            if not os.path.exists(pdf_path_or_url):
                print(f"Error: PDF file not found at {pdf_path_or_url}")
                return None

            title = os.path.basename(pdf_path_or_url)
            pdf_file = open(pdf_path_or_url, 'rb')

        # Process the PDF
        reader = PyPDF2.PdfReader(pdf_file)
        print(f"PDF has {len(reader.pages)} pages")

        paragraphs = []
        for page_num in range(len(reader.pages)):
            text = reader.pages[page_num].extract_text()
            if text:
                # Split text into paragraphs based on newlines
                page_paragraphs = [p.strip() for p in text.split('\n') if p.strip()]
                paragraphs.extend(page_paragraphs)

        # Close the file if it's a local file
        if not is_url:
            pdf_file.close()

        print(f"Extracted {len(paragraphs)} text segments from PDF")

        # Clean up paragraphs - remove very short ones, merge related segments
        cleaned_paragraphs = []
        current_paragraph = ""

        for p in paragraphs:
            # Skip likely header/footer patterns, page numbers, etc.
            if len(p) < 20 or p.isdigit():
                continue

            # If it ends with a sentence-ending punctuation, it's a complete thought
            if p.endswith('.') or p.endswith('?') or p.endswith('!'):
                if current_paragraph:
                    current_paragraph += " " + p
                    cleaned_paragraphs.append(current_paragraph)
                    current_paragraph = ""
                else:
                    cleaned_paragraphs.append(p)
            else:
                # It's a partial paragraph or segment, accumulate it
                if current_paragraph:
                    current_paragraph += " " + p
                else:
                    current_paragraph = p

        # Don't forget any remaining text
        if current_paragraph:
            cleaned_paragraphs.append(current_paragraph)

    except Exception as e:
        print(f"Error extracting PDF content: {e}")
        return None

    result = {
        'source_type': 'pdf',
        'file_path': pdf_path_or_url,
        'title': title,
        'paragraphs': cleaned_paragraphs
    }

    return result

def preview_content(content, max_paragraphs=5):
    """Generate a preview of the content that would be added to the corpus"""
    if content['source_type'] == 'web':
        preview = f"\n=== {content['title']} (Web) ===\n\n"
    else:  # PDF
        preview = f"\n=== {content['title']} (PDF) ===\n\n"

    # Add first few paragraphs
    paragraphs_to_show = min(max_paragraphs, len(content['paragraphs']))
    for i in range(paragraphs_to_show):
        preview += content['paragraphs'][i] + "\n\n"

    # Add indication if there are more paragraphs
    if len(content['paragraphs']) > max_paragraphs:
        preview += f"[...and {len(content['paragraphs']) - max_paragraphs} more paragraphs...]\n"

    return preview

def add_to_corpus(content, corpus_file, append=True):
    """Add content to corpus file"""
    mode = 'a' if append else 'w'

    if content['source_type'] == 'web':
        corpus_text = f"\n\n=== {content['title']} (Web: {content['url']}) ===\n\n"
    else:  # PDF
        corpus_text = f"\n\n=== {content['title']} (PDF) ===\n\n"

    for paragraph in content['paragraphs']:
        if paragraph and len(paragraph) > 20:  # Skip very short paragraphs
            corpus_text += paragraph + "\n\n"

    with open(corpus_file, mode, encoding='utf-8') as f:
        f.write(corpus_text)

    print(f"{'Added to' if append else 'Created'} corpus file: {corpus_file}")
    print(f"Added {len(content['paragraphs'])} paragraphs, {len(corpus_text)} characters")

# Example usage
if __name__ == "__main__":
    corpus_file = "corpus.txt"

    # Ask user for source type
    source_type = input("Extract from [1] Website or [2] PDF? (Enter 1 or 2): ").strip()

    if source_type == '1':
        # Extract from website
        url = input("Enter a URL to scrape: ")
        content = extract_page_content(url)
    elif source_type == '2':
        # Extract from PDF
        pdf_path_or_url = input("Enter the path or URL to your PDF file: ")
        content = extract_pdf_content(pdf_path_or_url)
        if not content:
            print("Failed to extract content from PDF. Exiting.")
            exit()
    else:
        print("Invalid option. Exiting.")
        exit()

    # Check if content was successfully extracted
    if content is None:
        print("Failed to extract content. Exiting.")
        exit()

    # Print summary
    print(f"\nSource: {content['title']}")
    print(f"Found {len(content['paragraphs'])} paragraphs")

    # Preview the content
    preview = preview_content(content)
    print("\nPREVIEW OF CONTENT TO ADD:")
    print("-" * 50)
    print(preview)
    print("-" * 50)

    # Ask user if they want to add to corpus
    add_choice = input(f"\nDo you want to add this content to {corpus_file}? (y/n): ").lower()

    if add_choice == 'y':
        # Check if corpus file exists
        file_exists = os.path.isfile(corpus_file)

        if file_exists:
            append_choice = input(f"{corpus_file} already exists. Append to it? (y/n): ").lower()
            append = append_choice == 'y'
        else:
            append = False

        add_to_corpus(content, corpus_file, append)

    # Save the raw extraction data to a JSON file
    if content['source_type'] == 'web':
        output_file = 'page_content.json'
    else:
        output_file = 'pdf_content.json'

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(content, f, indent=4, ensure_ascii=False)
    print(f"\nRaw extraction data saved to {output_file}")
# Out:
# Extract from [1] Website or [2] PDF? (Enter 1 or 2): 1
# Enter a URL to scrape: https://www.pittsburghpa.gov/Home
#
# Source: Home - Pittsburgh, PA
# Found 20 paragraphs
#
# PREVIEW OF CONTENT TO ADD:
# --------------------------------------------------
#
# === Home - Pittsburgh, PA (Web) ===
#
# Published on March 07, 2025
# FORBES AVENUE CLOSURE:  FRIDAY, MARCH 7 THROUGH MONDAY, MARCH 10
# FORBES AVENUE CLOSURE:  FRIDAY, MARCH 7 THROUGH MONDAY, MARCH 10
# Read Full Story
#
#
#
#
#
#
#
#
#
# Published on March 07, 2025
# Mayor Gainey proposes LOOP tax relief program to City Council
# Mayor Ed Gainey submits legislation to Council creating Groundbreaking Longtime Owner Occupant Tax Exemption Program (LOOP)
# Read Full Story
#
#
#
#
#
#
#
#
#
# Published on March 06, 2025
# Pittsburgh Food Justice Fund Grants Open March 10, 2025!
# PITTSBURGH’S FOOD JUSTICE FUND GRASSROOTS GRANTS PROGRAM APPLICATIONS OPEN MARCH 10, 2025
# Read Full Story
#
#
#
#
#
#
#
#
#
# Published on March 04, 2025
# Acting Police Chief Chris Ragland Announces Retirement
# Acting Police Chief Chris Ragland Announces Retirement After 30 Years of Dedicated Service to Pittsburgh, Transitioning to Private Sector
# Read Full Story
#
#
#
#
# View All News
#
# Published on March 07, 2025
#
# FORBES AVENUE CLOSURE:  FRIDAY, MARCH 7 THROUGH MONDAY, MARCH 10
#
# Published on March 07, 2025
#
# Mayor Ed Gainey submits legislation to Council creating Groundbreaking Longtime Owner Occupant Tax Exemption Program (LOOP)
#
# [...and 15 more paragraphs...]
#
# --------------------------------------------------
#
# Do you want to add this content to corpus.txt? (y/n): y
# corpus.txt already exists. Append to it? (y/n): y
# Added to corpus file: corpus.txt
# Added 20 paragraphs, 1749 characters
#
# Raw extraction data saved to page_content.json
